# %%
import os
import re
import pickle
import gensim

import numpy as np

import matplotlib.pyplot as plt

# %%
import sys
sys.path.append('../scripts')
from utils import predict, predict_multi_line_text, load_data

sys.path.append('../')
from config import entity_to_acronyms, acronyms_to_entities
# Out:
# [nltk_data] Error loading punkt: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1131)>
# [nltk_data] Error loading stopwords: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1131)>

# %%
# from importlib import reload

# import utils
# reload(utils)

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input, Embedding, Bidirectional, LSTM, Dense

# %%
from config import entity_to_acronyms, acronyms_to_entities

# %%
data_dir = '../data'
model_dir = '../models'

# %%
(train_sequences_padded, train_labels), (val_sequences_padded, val_labels), (test_sequences_padded, test_labels), label_to_index, index_to_label = load_data(data_dir)

# %%
if train_sequences_padded.shape[1] != train_labels.shape[1]:
    print('Sequence length mismatch')

# %%
# Load the tokenizer from file
with open('../data/tokenizer.pickle', 'rb') as handle:
    tokenizer = pickle.load(handle)

# %% [markdown]
# ## Model parameters

# %%
INPUT_DIM = len(tokenizer.word_index)+1
EMBEDDING_DIM = 200
NUM_CLASSES = len(label_to_index)
MAX_LENGTH = train_sequences_padded.shape[1]

LSTM1_UNITS = 64
LSTM2_UNITS = 32
DENSE_DIM = 64

DROPOUT = 0.2
BATCH_SIZE = 32
EPOCHS = 20

# %% [markdown]
# ## Load the BioWordVec vectors

# %%
path_to_vectors = os.path.join(data_dir, 'embedding_vectors', 'BioWordVec_PubMed_MIMICIII_d200.vec.bin')
biowv = gensim.models.KeyedVectors.load_word2vec_format(path_to_vectors, binary=True)

# %% [markdown]
# ## Create embedding layer using the BioWordVec vectors

# %%
embedding_matrix = np.zeros((INPUT_DIM, EMBEDDING_DIM))
for word, i in tokenizer.word_index.items():
    if word in biowv.index_to_key:
        embedding_matrix[i] = biowv[word]
        
embedding_layer = tf.keras.layers.Embedding(
    INPUT_DIM,
    EMBEDDING_DIM,
    embeddings_initializer=tf.keras.initializers.Constant(embedding_matrix),
    input_length=MAX_LENGTH,
    trainable=False
)

# %% [markdown]
# ## Building Model

# %%
from keras import backend as K

def precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    _precision = true_positives / (predicted_positives + K.epsilon())
    return _precision

def recall(y_true, y_pred):
    """Compute recall metric"""
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

def f1_score(y_true, y_pred):
    """Compute f1-score metric"""
    _precision = precision(y_true, y_pred)
    _recall = recall(y_true, y_pred)
    f1_score = 2 * ((_precision * _recall) / (_precision + _recall + K.epsilon()))
    return f1_score

# %%
# Define the model architecture
model = tf.keras.models.Sequential([
    embedding_layer,
    Bidirectional(LSTM(units=LSTM1_UNITS, return_sequences=True)),
    Bidirectional(LSTM(units=LSTM2_UNITS, return_sequences=True)),
    Dense(DENSE_DIM, activation='relu'),
    Dense(NUM_CLASSES, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy', precision, recall, f1_score])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 200)          1393800
#
#  bidirectional (Bidirectiona  (None, 100, 128)         135680
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 100, 64)          41216
#  nal)
#
#  dense (Dense)               (None, 100, 64)           4160
#
#  dense_1 (Dense)             (None, 100, 79)           5135
#
# =================================================================
# Total params: 1,579,991
# Trainable params: 186,191
# Non-trainable params: 1,393,800
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    train_sequences_padded, 
    train_labels, 
    epochs=EPOCHS, 
    validation_data=(val_sequences_padded, val_labels)
)
# Out:
# Epoch 1/20
# 2023-04-09 12:41:03.610843: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 95/95 [==============================] - 10s 71ms/step - loss: 1.0698 - accuracy: 0.8954 - precision: 0.7714 - recall: 0.7157 - f1_score: 0.7415 - val_loss: 0.3869 - val_accuracy: 0.9129 - val_precision: 0.9880 - val_recall: 0.8856 - val_f1_score: 0.9340
# Epoch 2/20
# 95/95 [==============================] - 6s 67ms/step - loss: 0.3747 - accuracy: 0.9068 - precision: 0.9964 - recall: 0.8788 - f1_score: 0.9338 - val_loss: 0.3742 - val_accuracy: 0.9130 - val_precision: 0.9832 - val_recall: 0.8957 - val_f1_score: 0.9374
# Epoch 3/20
# 95/95 [==============================] - 7s 72ms/step - loss: 0.3456 - accuracy: 0.9129 - precision: 0.9923 - recall: 0.8906 - f1_score: 0.9387 - val_loss: 0.3518 - val_accuracy: 0.9181 - val_precision: 0.9862 - val_recall: 0.8966 - val_f1_score: 0.9392
# Epoch 4/20
# 95/95 [==============================] - 7s 69ms/step - loss: 0.3070 - accuracy: 0.9189 - precision: 0.9925 - recall: 0.8930 - f1_score: 0.9401 - val_loss: 0.3282 - val_accuracy: 0.9219 - val_precision: 0.9824 - val_recall: 0.9007 - val_f1_score: 0.9398
# Epoch 5/20
# 95/95 [==============================] - 7s 73ms/step - loss: 0.2750 - accuracy: 0.9251 - precision: 0.9920 - recall: 0.8955 - f1_score: 0.9412 - val_loss: 0.3166 - val_accuracy: 0.9256 - val_precision: 0.9819 - val_recall: 0.9027 - val_f1_score: 0.9406
# Epoch 6/20
# 95/95 [==============================] - 7s 75ms/step - loss: 0.2503 - accuracy: 0.9305 - precision: 0.9905 - recall: 0.8998 - f1_score: 0.9430 - val_loss: 0.3069 - val_accuracy: 0.9283 - val_precision: 0.9810 - val_recall: 0.9042 - val_f1_score: 0.9410
# Epoch 7/20
# 95/95 [==============================] - 7s 73ms/step - loss: 0.2305 - accuracy: 0.9355 - precision: 0.9892 - recall: 0.9052 - f1_score: 0.9453 - val_loss: 0.2993 - val_accuracy: 0.9306 - val_precision: 0.9770 - val_recall: 0.9096 - val_f1_score: 0.9421
# Epoch 8/20
# 95/95 [==============================] - 7s 71ms/step - loss: 0.2149 - accuracy: 0.9393 - precision: 0.9880 - recall: 0.9105 - f1_score: 0.9477 - val_loss: 0.2946 - val_accuracy: 0.9329 - val_precision: 0.9746 - val_recall: 0.9138 - val_f1_score: 0.9432
# Epoch 9/20
# 95/95 [==============================] - 6s 64ms/step - loss: 0.2011 - accuracy: 0.9428 - precision: 0.9873 - recall: 0.9158 - f1_score: 0.9502 - val_loss: 0.2902 - val_accuracy: 0.9345 - val_precision: 0.9735 - val_recall: 0.9157 - val_f1_score: 0.9437
# Epoch 10/20
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1904 - accuracy: 0.9455 - precision: 0.9863 - recall: 0.9203 - f1_score: 0.9521 - val_loss: 0.2820 - val_accuracy: 0.9355 - val_precision: 0.9726 - val_recall: 0.9181 - val_f1_score: 0.9445
# Epoch 11/20
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1806 - accuracy: 0.9484 - precision: 0.9856 - recall: 0.9248 - f1_score: 0.9542 - val_loss: 0.2869 - val_accuracy: 0.9363 - val_precision: 0.9704 - val_recall: 0.9208 - val_f1_score: 0.9449
# Epoch 12/20
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1716 - accuracy: 0.9508 - precision: 0.9851 - recall: 0.9288 - f1_score: 0.9561 - val_loss: 0.2880 - val_accuracy: 0.9371 - val_precision: 0.9676 - val_recall: 0.9240 - val_f1_score: 0.9453
# Epoch 13/20
# 95/95 [==============================] - 6s 64ms/step - loss: 0.1645 - accuracy: 0.9524 - precision: 0.9848 - recall: 0.9318 - f1_score: 0.9576 - val_loss: 0.2866 - val_accuracy: 0.9388 - val_precision: 0.9689 - val_recall: 0.9238 - val_f1_score: 0.9458
# Epoch 14/20
# 95/95 [==============================] - 6s 65ms/step - loss: 0.1574 - accuracy: 0.9549 - precision: 0.9847 - recall: 0.9352 - f1_score: 0.9593 - val_loss: 0.2843 - val_accuracy: 0.9391 - val_precision: 0.9669 - val_recall: 0.9257 - val_f1_score: 0.9458
# Epoch 15/20
# 95/95 [==============================] - 6s 65ms/step - loss: 0.1502 - accuracy: 0.9566 - precision: 0.9847 - recall: 0.9380 - f1_score: 0.9608 - val_loss: 0.2823 - val_accuracy: 0.9395 - val_precision: 0.9666 - val_recall: 0.9260 - val_f1_score: 0.9459
# Epoch 16/20
# 95/95 [==============================] - 6s 65ms/step - loss: 0.1455 - accuracy: 0.9580 - precision: 0.9845 - recall: 0.9406 - f1_score: 0.9620 - val_loss: 0.2934 - val_accuracy: 0.9399 - val_precision: 0.9640 - val_recall: 0.9289 - val_f1_score: 0.9461
# Epoch 17/20
# 95/95 [==============================] - 6s 65ms/step - loss: 0.1399 - accuracy: 0.9594 - precision: 0.9844 - recall: 0.9426 - f1_score: 0.9630 - val_loss: 0.2927 - val_accuracy: 0.9400 - val_precision: 0.9637 - val_recall: 0.9292 - val_f1_score: 0.9462
# Epoch 18/20
# 95/95 [==============================] - 7s 69ms/step - loss: 0.1343 - accuracy: 0.9609 - precision: 0.9846 - recall: 0.9452 - f1_score: 0.9645 - val_loss: 0.2952 - val_accuracy: 0.9409 - val_precision: 0.9641 - val_recall: 0.9293 - val_f1_score: 0.9464
# Epoch 19/20
# 95/95 [==============================] - 6s 68ms/step - loss: 0.1291 - accuracy: 0.9624 - precision: 0.9846 - recall: 0.9475 - f1_score: 0.9657 - val_loss: 0.2966 - val_accuracy: 0.9408 - val_precision: 0.9627 - val_recall: 0.9305 - val_f1_score: 0.9463
# Epoch 20/20
# 95/95 [==============================] - 7s 70ms/step - loss: 0.1239 - accuracy: 0.9637 - precision: 0.9848 - recall: 0.9496 - f1_score: 0.9668 - val_loss: 0.3044 - val_accuracy: 0.9404 - val_precision: 0.9617 - val_recall: 0.9315 - val_f1_score: 0.9464

# %%
import matplotlib.pyplot as plt

def plot_graphs(history):
    fig, axs = plt.subplots(2, 2, figsize=(12, 8))
    
    axs[0, 0].plot(history.history['accuracy'])
    axs[0, 0].plot(history.history['val_accuracy'])
    axs[0, 0].set_title('Model Accuracy')
    axs[0, 0].set_ylabel('Accuracy')
    axs[0, 0].legend(['train', 'val'], loc='best')
    
    axs[0, 1].plot(history.history['loss'])
    axs[0, 1].plot(history.history['val_loss'])
    axs[0, 1].set_title('Model Loss')
    axs[0, 1].set_ylabel('Loss')
    axs[0, 1].legend(['train', 'val'], loc='best')
    
    axs[1, 0].plot(history.history['recall'])
    axs[1, 0].plot(history.history['val_recall'])
    axs[1, 0].set_title('Model Recall')
    axs[1, 0].set_ylabel('Recall')
    axs[1, 0].legend(['train', 'val'], loc='best')
    
    axs[1, 1].plot(history.history['f1_score'])
    axs[1, 1].plot(history.history['val_f1_score'])
    axs[1, 1].set_title('Model F1 Score')
    axs[1, 1].set_ylabel('F1 Score')
    axs[1, 1].legend(['train', 'val'], loc='best')
    
    plt.tight_layout()
    plt.show()

# %%
# Plot the training history
plot_graphs(history)

# %%
from sklearn.metrics import classification_report

# Get the model predictions
y_pred = model.predict(test_sequences_padded)

# Convert the predictions from one-hot encoded format to the label format
y_pred_labels = np.argmax(y_pred, axis=2)
test_labels_labels = np.argmax(test_labels, axis=2)

# Print the classification report
print(classification_report(test_labels_labels.reshape(-1), y_pred_labels.reshape(-1), zero_division=0))
# Out:
# 28/28 [==============================] - 1s 24ms/step
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        15
#            2       0.41      0.35      0.38        37
#            3       0.77      0.92      0.84        36
#            4       0.00      0.00      0.00         4
#            6       0.45      0.51      0.48       467
#            7       0.65      0.72      0.69       100
#            8       0.00      0.00      0.00        16
#            9       0.50      0.07      0.12        56
#           10       0.46      0.56      0.50        97
#           11       0.40      0.19      0.26       478
#           12       0.58      0.53      0.55       684
#           13       0.26      0.36      0.30       236
#           14       0.48      0.48      0.48        65
#           15       0.27      0.44      0.34        45
#           16       0.00      0.00      0.00        16
#           17       0.00      0.00      0.00        11
#           19       0.21      0.13      0.16        55
#           20       0.40      0.39      0.39       465
#           21       0.00      0.00      0.00         2
#           22       0.49      0.58      0.53       143
#           23       0.60      0.59      0.60        49
#           24       0.00      0.00      0.00         6
#           25       0.00      0.00      0.00         2
#           26       0.00      0.00      0.00         2
#           27       0.00      0.00      0.00         3
#           28       0.43      0.38      0.40         8
#           29       0.00      0.00      0.00        11
#           30       0.47      0.47      0.47        74
#           31       0.76      0.91      0.83        32
#           32       0.00      0.00      0.00         7
#           33       0.42      0.38      0.40       558
#           34       0.00      0.00      0.00        12
#           35       0.00      0.00      0.00        10
#           36       0.31      0.29      0.30       163
#           37       0.00      0.00      0.00        10
#           38       0.00      0.00      0.00         4
#           40       0.00      0.00      0.00        11
#           41       0.00      0.00      0.00         7
#           42       0.91      0.90      0.91        71
#           43       0.20      0.09      0.13        11
#           45       0.53      0.51      0.52       505
#           46       0.00      0.00      0.00         1
#           47       0.00      0.00      0.00        10
#           48       0.00      0.00      0.00        15
#           49       0.53      0.55      0.54       161
#           50       0.43      0.10      0.16       460
#           51       0.66      0.60      0.63       924
#           52       0.37      0.38      0.38       199
#           53       0.55      0.49      0.51       107
#           54       0.28      0.32      0.30        59
#           55       0.00      0.00      0.00        78
#           56       0.00      0.00      0.00        13
#           58       0.34      0.43      0.38       188
#           59       0.47      0.28      0.35       385
#           60       0.00      0.00      0.00         2
#           61       0.51      0.39      0.44       119
#           62       0.55      0.69      0.61        48
#           63       0.00      0.00      0.00         9
#           64       0.00      0.00      0.00         4
#           65       0.00      0.00      0.00         2
#           66       0.00      0.00      0.00         1
#           67       0.00      0.00      0.00         3
#           68       0.00      0.00      0.00         9
#           69       0.00      0.00      0.00         9
#           70       0.00      0.00      0.00         1
#           71       0.30      0.29      0.30       354
#           72       0.00      0.00      0.00         3
#           73       0.00      0.00      0.00         6
#           74       0.27      0.24      0.25       127
#           75       0.00      0.00      0.00         8
#           76       0.00      0.00      0.00         7
#           78       0.98      0.99      0.98     79004
#
#     accuracy                           0.94     86900
#    macro avg       0.24      0.23      0.23     86900
# weighted avg       0.93      0.94      0.93     86900

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

report = classification_report(test_labels_labels.reshape(-1), y_pred_labels.reshape(-1), zero_division=0, output_dict=True)
plt.subplots(figsize=(20, 20))
sns.heatmap(pd.DataFrame(report).iloc[:-1, :].T, annot=True, cmap='Blues', fmt='.2f')
plt.show()

# %% [markdown]
# In the case of NER task, all three metrics - precision, recall, and F1 score - are important.
#
# * Precision measures the proportion of predicted entities that are actually correct. In NER, precision means how many of the predicted named entities are actually true named entities.
#
# * Recall measures the proportion of actual entities that are correctly identified by the model. In NER, recall means how many true named entities are correctly identified by the model.
#
# * F1 score is the harmonic mean of precision and recall. It is a balanced metric that takes into account both precision and recall. F1 score is commonly used in NER evaluation as it takes into account both false positives and false negatives.
#
# A high precision score means that the model is making very few false predictions, while a high recall score means that the model is identifying a high proportion of the true named entities. A high F1 score indicates that the model is both precise and recallful.

# %% [markdown]
# ## Save model

# %%
model.save(os.path.join(model_dir, 'model_3.h5'))

# %% [markdown]
# ## Load the model

# %%
# Register the custom metric function
tf.keras.utils.get_custom_objects()[precision.__name__] = precision
tf.keras.utils.get_custom_objects()[recall.__name__] = recall
tf.keras.utils.get_custom_objects()[f1_score.__name__] = f1_score

# %%
model_3 = tf.keras.models.load_model(os.path.join(model_dir, 'model_3.h5'))

# %%
# Evaluate the model on the test set
test_loss, test_accuracy, test_precision, test_recall, test_f1_score = model_3.evaluate(test_sequences_padded, test_labels)

# Print the test loss and accuracy
print('Test loss:', test_loss)
print('Test accuracy:', test_accuracy)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test f1_score:', test_f1_score)
# Out:
# 28/28 [==============================] - 1s 20ms/step - loss: 0.3269 - accuracy: 0.9375 - precision: 0.9600 - recall: 0.9294 - f1_score: 0.9444
# Test loss: 0.32691270112991333
# Test accuracy: 0.9375143647193909
# Test precision: 0.9600387811660767
# Test recall: 0.9293550252914429
# Test f1_score: 0.9444414973258972

# %%
predict(
    "The patient underwent an electrophysiologic study with mapping of the accessory pathway, followed by radiofrequency ablation (interruption of the pathway using the heat generated by electromagnetic waves at the tip of an ablation catheter).",
    model_3, 
    index_to_label,
    acronyms_to_entities, 
    MAX_LENGTH
)
# Out:
# 2023-04-16 13:44:14.818655: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 1/1 [==============================] - 1s 688ms/step
# Predicted Named Entities:
# patient: O
# underwent: O
# electrophysiologic: Diagnostic_procedure
# study: Diagnostic_procedure
# mapping: O
# accessory: Distance
# pathway: Biological_structure
# followed: Therapeutic_procedure
# radiofrequency: Therapeutic_procedure
# ablation: O
# interruption: Therapeutic_procedure
# pathway: O
# using: O
# heat: Therapeutic_procedure
# generated: Therapeutic_procedure
# electromagnetic: Therapeutic_procedure
# waves: O
# tip: O
# ablation: O
# catheter: O
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The patient underwent an
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     electrophysiologic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Diagnostic_procedure</span>
# </mark>
#
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     study
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Diagnostic_procedure</span>
# </mark>
#  with mapping of the
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     accessory
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Distance</span>
# </mark>
#
# <mark class="entity" style="background: #9ddfd3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pathway
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Biological_structure</span>
# </mark>
# ,
# <mark class="entity" style="background: #e6ccb2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     followed
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Therapeutic_procedure</span>
# </mark>
#  by
# <mark class="entity" style="background: #e6ccb2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     radiofrequency
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Therapeutic_procedure</span>
# </mark>
#  ablation (
# <mark class="entity" style="background: #e6ccb2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     interruption
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Therapeutic_procedure</span>
# </mark>
#  of the pathway using the
# <mark class="entity" style="background: #e6ccb2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     heat
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Therapeutic_procedure</span>
# </mark>
#
# <mark class="entity" style="background: #e6ccb2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     generated
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Therapeutic_procedure</span>
# </mark>
#  by
# <mark class="entity" style="background: #e6ccb2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     electromagnetic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Therapeutic_procedure</span>
# </mark>
#  waves at the tip of an ablation catheter).</div></span>

# %%
predict(
    "A 57-year-old man presented to the emergency department with a 2-day history of worsening shortness of breath and chest pain. He reported no recent travel or sick contacts. His medical history was significant for hypertension, dyslipidemia, and type 2 diabetes mellitus. On examination, he was tachycardic and tachypneic, with oxygen saturation of 88% on room air. Chest radiography revealed bilateral opacities consistent with pulmonary edema. The patient was admitted to the intensive care unit for management of acute decompensated heart failure. He was started on intravenous diuretics and inotropic support with dobutamine. Over the next several days, his symptoms improved and he was discharged to home with instructions to follow up with his primary care provider in 1 week.",
    model, 
    tokenizer, 
    index_to_label,
    acronyms_to_entities, 
    MAX_LENGTH
)
# Out:
# 1/1 [==============================] - 0s 14ms/step
# Predicted Named Entities:
# 57: Age
# year: Age
# old: Age
# man: Sex
# presented: Nonbiological_location
# emergency: Nonbiological_location
# department: Duration
# 2: Date
# day: O
# history: Sign_symptom
# worsening: Sign_symptom
# shortness: Biological_structure
# breath: Sign_symptom
# chest: History
# pain: History
# reported: History
# recent: History
# travel: History
# sick: Severity
# contacts: History
# medical: History
# history: History
# significant: History
# hypertension: History
# dyslipidemia: History
# type: O
# 2: Detailed_description
# diabetes: Diagnostic_procedure
# mellitus: Diagnostic_procedure
# examination: Lab_value
# tachycardic: Detailed_description
# tachypneic: Detailed_description
# oxygen: Biological_structure
# saturation: Diagnostic_procedure
# 88: Detailed_description
# room: O
# air: Distance
# chest: Sign_symptom
# radiography: O
# revealed: Nonbiological_location
# bilateral: Nonbiological_location
# opacities: Nonbiological_location
# consistent: O
# pulmonary: Detailed_description
# edema: Distance
# patient: Distance
# admitted: Administration
# intensive: Medication
# care: Medication
# unit: Medication
# management: Duration
# acute: Duration
# decompensated: History
# heart: Clinical_event
# failure: Nonbiological_location
# started: Nonbiological_location
# intravenous: Date
# diuretics: Date
# inotropic: O
# support: O
# dobutamine: O
# next: O
# several: O
# days: O
# symptoms: O
# improved: O
# discharged: O
# home: O
# instructions: O
# follow: O
# primary: O
# care: O
# provider: O
# 1: O
# week: O
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     57
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# -
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# -
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
#
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     man
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sex</span>
# </mark>
#
# <mark class="entity" style="background: #f7a399; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     presented
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nonbiological_location</span>
# </mark>
#  to the
# <mark class="entity" style="background: #f7a399; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     emergency
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nonbiological_location</span>
# </mark>
#
# <mark class="entity" style="background: #ffdfba; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     department
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Duration</span>
# </mark>
#  with a
# <mark class="entity" style="background: #f1f0d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Date</span>
# </mark>
# -day
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     history
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#  of
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     worsening
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#
# <mark class="entity" style="background: #9ddfd3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     shortness
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Biological_structure</span>
# </mark>
#  of
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     breath
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#  and
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chest
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# . He
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     reported
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  no
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     recent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     travel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  or
# <mark class="entity" style="background: #ffb347; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sick
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Severity</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     contacts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# . His
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     medical
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     history
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  was
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     significant
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  for
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hypertension
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# ,
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dyslipidemia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# , and type
# <mark class="entity" style="background: #ffb347; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Detailed_description</span>
# </mark>
#
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     diabetes
#     <sp

# %%
predict_multi_line_text(
    
    "A 57-year-old man presented to the emergency department with a 2-day history of worsening shortness of breath and chest pain. He reported no recent travel or sick contacts. His medical history was significant for hypertension, dyslipidemia, and type 2 diabetes mellitus. On examination, he was tachycardic and tachypneic, with oxygen saturation of 88% on room air. Chest radiography revealed bilateral opacities consistent with pulmonary edema. The patient was admitted to the intensive care unit for management of acute decompensated heart failure. He was started on intravenous diuretics and inotropic support with dobutamine. Over the next several days, his symptoms improved and he was discharged to home with instructions to follow up with his primary care provider in 1 week.",
    model, 
    tokenizer, 
    index_to_label,
    acronyms_to_entities, 
    MAX_LENGTH
    
)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# Predicted Named Entities:
# 57: Age
# year: Age
# old: Age
# man: Sex
# presented: Nonbiological_location
# emergency: Nonbiological_location
# department: Duration
# 2: Duration
# day: O
# history: Sign_symptom
# worsening: Sign_symptom
# shortness: Biological_structure
# breath: Sign_symptom
# chest: O
# pain: O
#
#
#
#
# reported: O
# recent: History
# travel: History
# sick: O
# contacts: O
#
#
#
#
# medical: O
# history: O
# significant: O
# hypertension: History
# dyslipidemia: History
# type: History
# 2: History
# diabetes: History
# mellitus: History
#
#
#
#
# examination: Diagnostic_procedure
# tachycardic: Sign_symptom
# tachypneic: Diagnostic_procedure
# oxygen: Diagnostic_procedure
# saturation: Lab_value
# 88: Detailed_description
# room: Detailed_description
# air: O
#
#
#
#
# chest: Biological_structure
# radiography: Diagnostic_procedure
# revealed: Detailed_description
# bilateral: O
# opacities: Distance
# consistent: Sign_symptom
# pulmonary: O
# edema: O
#
#
#
#
# patient: O
# admitted: Nonbiological_location
# intensive: Nonbiological_location
# care: Nonbiological_location
# unit: O
# management: Distance
# acute: Distance
# decompensated: Distance
# heart: O
# failure: O
#
#
#
#
# started: Administration
# intravenous: Medication
# diuretics: Medication
# inotropic: Medication
# support: O
# dobutamine: O
#
#
#
#
# next: O
# several: Nonbiological_location
# days: Nonbiological_location
# symptoms: Clinical_event
# improved: Nonbiological_location
# discharged: Nonbiological_location
# home: Date
# instructions: Date
# follow: O
# primary: O
# care: O
# provider: O
# 1: O
# week: O
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     57
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# -
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# -
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
#
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     man
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sex</span>
# </mark>
#
# <mark class="entity" style="background: #f7a399; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     presented
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nonbiological_location</span>
# </mark>
#  to the
# <mark class="entity" style="background: #f7a399; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     emergency
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nonbiological_location</span>
# </mark>
#
# <mark class="entity" style="background: #ffdfba; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     department
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Duration</span>
# </mark>
#  with a
# <mark class="entity" style="background: #ffdfba; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Duration</span>
# </mark>
# -day
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     history
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#  of
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     worsening
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#
# <mark class="entity" style="background: #9ddfd3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     shortness
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Biological_structure</span>
# </mark>
#  of
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     breath
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#  and chest pain. He reported no
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     recent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     travel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  or sick contacts. His medical history was significant for
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hypertension
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# ,
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dyslipidemia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# , and
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     type
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     diabetes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mellitus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# . On
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     examination
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Diagnostic_procedure</span>
# </mark>
# , he was
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tachycardic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#  and
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tachypneic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Diagnostic_procedure</span>
# </mark>
# , with
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     oxygen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Diagnostic_procedure</span>
# </mark>
#
# <mark class="entity" style="background: #f4b3c2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     saturation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Lab_value</span>
# </mark>
#  of
# <mark class="entity
