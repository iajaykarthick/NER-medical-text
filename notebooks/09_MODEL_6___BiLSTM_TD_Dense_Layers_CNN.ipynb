# %%
import os
import re
import pickle

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import classification_report

# %%
import tensorflow as tf

# %%
import sys
sys.path.append('../scripts')
from utils import predict, predict_multi_line_text, load_data

sys.path.append('../')
from config import entity_to_acronyms, acronyms_to_entities
# Out:
# [nltk_data] Error loading punkt: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1131)>
# [nltk_data] Error loading stopwords: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1131)>

# %%
# from importlib import reload

# import utils
# reload(utils)

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input, Embedding, Bidirectional, LSTM, Dense

# %%
data_dir = '../data'
model_dir = '../models'

# %%
(train_sequences_padded, train_labels), (val_sequences_padded, val_labels), (test_sequences_padded, test_labels), label_to_index, index_to_label = load_data(data_dir)

# %%
if train_sequences_padded.shape[1] != train_labels.shape[1]:
    print('Sequence length mismatch')

# %%
# Load the tokenizer from file
with open('../data/tokenizer.pickle', 'rb') as handle:
    tokenizer = pickle.load(handle)

# %% [markdown]
# ## Model parameters

# %%
INPUT_DIM = len(tokenizer.word_index)+1
EMBEDDING_DIM = 64
NUM_CLASSES = len(label_to_index)
MAX_LENGTH = train_sequences_padded.shape[1]

LSTM_UNITS = 64
DENSE_UNITS = 64

DROPOUT_RATE = 0.2
BATCH_SIZE = 32
EPOCHS = 20

# %% [markdown]
# ## Building Model

# %%
from keras import backend as K

def precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    _precision = true_positives / (predicted_positives + K.epsilon())
    return _precision

def recall(y_true, y_pred):
    """Compute recall metric"""
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

def f1_score(y_true, y_pred):
    """Compute f1-score metric"""
    _precision = precision(y_true, y_pred)
    _recall = recall(y_true, y_pred)
    f1_score = 2 * ((_precision * _recall) / (_precision + _recall + K.epsilon()))
    return f1_score

# %%
model = tf.keras.models.Sequential([
    
    # Add a word embedding layer to learn the representations of words in the input text
    tf.keras.layers.Embedding(input_dim=INPUT_DIM, output_dim=EMBEDDING_DIM, input_length=MAX_LENGTH),
    
    # Add a Convolutional Neural Network (CNN) layer to capture local patterns in the text
    tf.keras.layers.Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'),
    
    # Add a Bidirectional LSTM layer to capture contextual information from both directions
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(units=LSTM_UNITS, return_sequences=True)),
    
    # Add a TimeDistributed dense layer to apply a dense layer to each time step of the LSTM output
    tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(units=DENSE_UNITS, activation='relu')),
    
    # Add a dropout layer to reduce overfitting
    tf.keras.layers.Dropout(rate=DROPOUT_RATE),
    
    # Add a dense layer with softmax activation to output the probabilities of each class
    tf.keras.layers.Dense(units=NUM_CLASSES, activation='softmax'),
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', precision, recall, f1_score])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 64)           446016
#
#  conv1d (Conv1D)             (None, 100, 32)           6176
#
#  bidirectional (Bidirectiona  (None, 100, 128)         49664
#  l)
#
#  time_distributed (TimeDistr  (None, 100, 64)          8256
#  ibuted)
#
#  dropout (Dropout)           (None, 100, 64)           0
#
#  dense_1 (Dense)             (None, 100, 79)           5135
#
# =================================================================
# Total params: 515,247
# Trainable params: 515,247
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
    train_sequences_padded, 
    train_labels, 
    epochs=EPOCHS, 
    validation_data=(val_sequences_padded, val_labels)
)
# Out:
# Epoch 1/20
# 2023-04-09 19:35:59.021692: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 95/95 [==============================] - 5s 33ms/step - loss: 1.0626 - accuracy: 0.8945 - precision: 0.8142 - recall: 0.7213 - f1_score: 0.7581 - val_loss: 0.3808 - val_accuracy: 0.9129 - val_precision: 0.9891 - val_recall: 0.8858 - val_f1_score: 0.9345
# Epoch 2/20
# 95/95 [==============================] - 3s 30ms/step - loss: 0.4002 - accuracy: 0.9063 - precision: 0.9925 - recall: 0.8765 - f1_score: 0.9308 - val_loss: 0.3761 - val_accuracy: 0.9129 - val_precision: 0.9863 - val_recall: 0.8890 - val_f1_score: 0.9351
# Epoch 3/20
# 95/95 [==============================] - 3s 30ms/step - loss: 0.3816 - accuracy: 0.9068 - precision: 0.9930 - recall: 0.8822 - f1_score: 0.9343 - val_loss: 0.3760 - val_accuracy: 0.9127 - val_precision: 0.9816 - val_recall: 0.8955 - val_f1_score: 0.9365
# Epoch 4/20
# 95/95 [==============================] - 3s 30ms/step - loss: 0.3583 - accuracy: 0.9100 - precision: 0.9920 - recall: 0.8910 - f1_score: 0.9387 - val_loss: 0.3712 - val_accuracy: 0.9145 - val_precision: 0.9812 - val_recall: 0.9014 - val_f1_score: 0.9396
# Epoch 5/20
# 95/95 [==============================] - 3s 30ms/step - loss: 0.3283 - accuracy: 0.9140 - precision: 0.9941 - recall: 0.8980 - f1_score: 0.9436 - val_loss: 0.3758 - val_accuracy: 0.9167 - val_precision: 0.9816 - val_recall: 0.9022 - val_f1_score: 0.9402
# Epoch 6/20
# 95/95 [==============================] - 3s 30ms/step - loss: 0.3049 - accuracy: 0.9180 - precision: 0.9954 - recall: 0.9001 - f1_score: 0.9453 - val_loss: 0.3880 - val_accuracy: 0.9192 - val_precision: 0.9798 - val_recall: 0.9046 - val_f1_score: 0.9406
# Epoch 7/20
# 95/95 [==============================] - 3s 30ms/step - loss: 0.2823 - accuracy: 0.9228 - precision: 0.9954 - recall: 0.9022 - f1_score: 0.9464 - val_loss: 0.3910 - val_accuracy: 0.9223 - val_precision: 0.9785 - val_recall: 0.9065 - val_f1_score: 0.9411
# Epoch 8/20
# 95/95 [==============================] - 3s 30ms/step - loss: 0.2540 - accuracy: 0.9302 - precision: 0.9941 - recall: 0.9086 - f1_score: 0.9494 - val_loss: 0.3871 - val_accuracy: 0.9253 - val_precision: 0.9774 - val_recall: 0.9098 - val_f1_score: 0.9423
# Epoch 9/20
# 95/95 [==============================] - 3s 30ms/step - loss: 0.2288 - accuracy: 0.9369 - precision: 0.9932 - recall: 0.9137 - f1_score: 0.9518 - val_loss: 0.3932 - val_accuracy: 0.9268 - val_precision: 0.9751 - val_recall: 0.9122 - val_f1_score: 0.9426
# Epoch 10/20
# 95/95 [==============================] - 3s 31ms/step - loss: 0.2089 - accuracy: 0.9416 - precision: 0.9922 - recall: 0.9182 - f1_score: 0.9538 - val_loss: 0.4011 - val_accuracy: 0.9283 - val_precision: 0.9742 - val_recall: 0.9142 - val_f1_score: 0.9432
# Epoch 11/20
# 95/95 [==============================] - 3s 31ms/step - loss: 0.1915 - accuracy: 0.9470 - precision: 0.9917 - recall: 0.9228 - f1_score: 0.9560 - val_loss: 0.4124 - val_accuracy: 0.9292 - val_precision: 0.9732 - val_recall: 0.9155 - val_f1_score: 0.9435
# Epoch 12/20
# 95/95 [==============================] - 3s 30ms/step - loss: 0.1759 - accuracy: 0.9518 - precision: 0.9914 - recall: 0.9276 - f1_score: 0.9584 - val_loss: 0.4258 - val_accuracy: 0.9303 - val_precision: 0.9709 - val_recall: 0.9168 - val_f1_score: 0.9431
# Epoch 13/20
# 95/95 [==============================] - 3s 30ms/step - loss: 0.1601 - accuracy: 0.9566 - precision: 0.9905 - recall: 0.9337 - f1_score: 0.9613 - val_loss: 0.4367 - val_accuracy: 0.9316 - val_precision: 0.9690 - val_recall: 0.9188 - val_f1_score: 0.9432
# Epoch 14/20
# 95/95 [==============================] - 3s 31ms/step - loss: 0.1458 - accuracy: 0.9606 - precision: 0.9896 - recall: 0.9402 - f1_score: 0.9643 - val_loss: 0.4547 - val_accuracy: 0.9328 - val_precision: 0.9645 - val_recall: 0.9226 - val_f1_score: 0.9431
# Epoch 15/20
# 95/95 [==============================] - 3s 31ms/step - loss: 0.1333 - accuracy: 0.9646 - precision: 0.9890 - recall: 0.9466 - f1_score: 0.9673 - val_loss: 0.4691 - val_accuracy: 0.9326 - val_precision: 0.9623 - val_recall: 0.9233 - val_f1_score: 0.9424
# Epoch 16/20
# 95/95 [==============================] - 3s 32ms/step - loss: 0.1212 - accuracy: 0.9677 - precision: 0.9888 - recall: 0.9526 - f1_score: 0.9704 - val_loss: 0.4876 - val_accuracy: 0.9337 - val_precision: 0.9594 - val_recall: 0.9256 - val_f1_score: 0.9422
# Epoch 17/20
# 95/95 [==============================] - 3s 32ms/step - loss: 0.1104 - accuracy: 0.9708 - precision: 0.9889 - recall: 0.9577 - f1_score: 0.9731 - val_loss: 0.5107 - val_accuracy: 0.9338 - val_precision: 0.9568 - val_recall: 0.9263 - val_f1_score: 0.9413
# Epoch 18/20
# 95/95 [==============================] - 3s 33ms/step - loss: 0.1008 - accuracy: 0.9734 - precision: 0.9890 - recall: 0.9622 - f1_score: 0.9754 - val_loss: 0.5247 - val_accuracy: 0.9332 - val_precision: 0.9558 - val_recall: 0.9272 - val_f1_score: 0.9413
# Epoch 19/20
# 95/95 [==============================] - 3s 32ms/step - loss: 0.0925 - accuracy: 0.9754 - precision: 0.9895 - recall: 0.9653 - f1_score: 0.9772 - val_loss: 0.5428 - val_accuracy: 0.9338 - val_precision: 0.9523 - val_recall: 0.9284 - val_f1_score: 0.9402
# Epoch 20/20
# 95/95 [==============================] - 3s 33ms/step - loss: 0.0851 - accuracy: 0.9773 - precision: 0.9899 - recall: 0.9687 - f1_score: 0.9792 - val_loss: 0.5600 - val_accuracy: 0.9339 - val_precision: 0.9517 - val_recall: 0.9290 - val_f1_score: 0.9402

# %%
import matplotlib.pyplot as plt

def plot_graphs(history):
    fig, axs = plt.subplots(2, 2, figsize=(12, 8))
    
    axs[0, 0].plot(history.history['accuracy'])
    axs[0, 0].plot(history.history['val_accuracy'])
    axs[0, 0].set_title('Model Accuracy')
    axs[0, 0].set_ylabel('Accuracy')
    axs[0, 0].legend(['train', 'val'], loc='best')
    
    axs[0, 1].plot(history.history['loss'])
    axs[0, 1].plot(history.history['val_loss'])
    axs[0, 1].set_title('Model Loss')
    axs[0, 1].set_ylabel('Loss')
    axs[0, 1].legend(['train', 'val'], loc='best')
    
    axs[1, 0].plot(history.history['recall'])
    axs[1, 0].plot(history.history['val_recall'])
    axs[1, 0].set_title('Model Recall')
    axs[1, 0].set_ylabel('Recall')
    axs[1, 0].legend(['train', 'val'], loc='best')
    
    axs[1, 1].plot(history.history['f1_score'])
    axs[1, 1].plot(history.history['val_f1_score'])
    axs[1, 1].set_title('Model F1 Score')
    axs[1, 1].set_ylabel('F1 Score')
    axs[1, 1].legend(['train', 'val'], loc='best')
    
    plt.tight_layout()
    plt.show()

# %%
# Plot the training history
plot_graphs(history)

# %%
from sklearn.metrics import classification_report

# Get the model predictions
y_pred = model.predict(test_sequences_padded)

# Convert the predictions from one-hot encoded format to the label format
y_pred_labels = np.argmax(y_pred, axis=2)
test_labels_labels = np.argmax(test_labels, axis=2)

# Print the classification report
print(classification_report(test_labels_labels.reshape(-1), y_pred_labels.reshape(-1), zero_division=0))
# Out:
# 28/28 [==============================] - 1s 8ms/step
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        15
#            2       0.28      0.14      0.18        37
#            3       0.83      0.83      0.83        36
#            4       0.00      0.00      0.00         4
#            6       0.40      0.40      0.40       467
#            7       0.60      0.47      0.53       100
#            8       0.00      0.00      0.00        16
#            9       0.00      0.00      0.00        56
#           10       0.43      0.51      0.46        97
#           11       0.26      0.27      0.26       478
#           12       0.54      0.51      0.52       684
#           13       0.24      0.17      0.20       236
#           14       0.42      0.28      0.33        65
#           15       0.21      0.13      0.16        45
#           16       0.00      0.00      0.00        16
#           17       0.00      0.00      0.00        11
#           19       0.16      0.11      0.13        55
#           20       0.35      0.31      0.33       465
#           21       0.00      0.00      0.00         2
#           22       0.36      0.36      0.36       143
#           23       0.48      0.55      0.51        49
#           24       0.00      0.00      0.00         6
#           25       0.00      0.00      0.00         2
#           26       0.00      0.00      0.00         2
#           27       0.00      0.00      0.00         3
#           28       0.33      0.38      0.35         8
#           29       0.00      0.00      0.00        11
#           30       0.52      0.16      0.25        74
#           31       0.81      0.91      0.85        32
#           32       0.00      0.00      0.00         7
#           33       0.35      0.35      0.35       558
#           34       0.00      0.00      0.00        12
#           35       0.00      0.00      0.00        10
#           36       0.16      0.12      0.13       163
#           37       0.00      0.00      0.00        10
#           38       0.00      0.00      0.00         4
#           40       0.00      0.00      0.00        11
#           41       0.00      0.00      0.00         7
#           42       0.88      0.92      0.90        71
#           43       0.14      0.27      0.19        11
#           45       0.48      0.47      0.48       505
#           46       0.00      0.00      0.00         1
#           47       0.00      0.00      0.00        10
#           48       0.00      0.00      0.00        15
#           49       0.49      0.55      0.52       161
#           50       0.20      0.22      0.21       460
#           51       0.59      0.55      0.57       924
#           52       0.24      0.20      0.22       199
#           53       0.41      0.40      0.41       107
#           54       0.23      0.20      0.21        59
#           55       0.00      0.00      0.00        78
#           56       0.25      0.23      0.24        13
#           58       0.34      0.35      0.34       188
#           59       0.38      0.21      0.27       385
#           60       0.00      0.00      0.00         2
#           61       0.37      0.28      0.32       119
#           62       0.41      0.46      0.43        48
#           63       0.00      0.00      0.00         9
#           64       0.00      0.00      0.00         4
#           65       0.00      0.00      0.00         2
#           66       0.00      0.00      0.00         1
#           67       0.00      0.00      0.00         3
#           68       0.00      0.00      0.00         9
#           69       0.00      0.00      0.00         9
#           70       0.00      0.00      0.00         1
#           71       0.28      0.25      0.26       354
#           72       0.00      0.00      0.00         3
#           73       0.00      0.00      0.00         6
#           74       0.21      0.17      0.19       127
#           75       0.00      0.00      0.00         8
#           76       0.00      0.00      0.00         7
#           78       0.98      0.99      0.98     79004
#
#     accuracy                           0.93     86900
#    macro avg       0.20      0.19      0.19     86900
# weighted avg       0.92      0.93      0.93     86900

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

report = classification_report(test_labels_labels.reshape(-1), y_pred_labels.reshape(-1), zero_division=0, output_dict=True)
plt.subplots(figsize=(20, 20))
sns.heatmap(pd.DataFrame(report).iloc[:-1, :].T, annot=True, cmap='Blues', fmt='.2f')
plt.show()

# %% [markdown]
# In the case of NER task, all three metrics - precision, recall, and F1 score - are important.
#
# * Precision measures the proportion of predicted entities that are actually correct. In NER, precision means how many of the predicted named entities are actually true named entities.
#
# * Recall measures the proportion of actual entities that are correctly identified by the model. In NER, recall means how many true named entities are correctly identified by the model.
#
# * F1 score is the harmonic mean of precision and recall. It is a balanced metric that takes into account both precision and recall. F1 score is commonly used in NER evaluation as it takes into account both false positives and false negatives.
#
# A high precision score means that the model is making very few false predictions, while a high recall score means that the model is identifying a high proportion of the true named entities. A high F1 score indicates that the model is both precise and recallful.

# %%
model.evaluate(test_sequences_padded, test_labels)
# Out:
# 28/28 [==============================] - 0s 10ms/step - loss: 0.6191 - accuracy: 0.9311 - precision: 0.9493 - recall: 0.9272 - f1_score: 0.9381
# [0.6190772652626038,
#  0.9310932159423828,
#  0.9492955207824707,
#  0.9271875023841858,
#  0.9381080865859985]

# %% [markdown]
# ## SAVE THE MODEL

# %%
model.save(os.path.join(model_dir, 'model_6.h5'))

# %% [markdown]
# ## LOAD THE MODEL

# %%
# Register the custom metric function
tf.keras.utils.get_custom_objects()[precision.__name__] = precision
tf.keras.utils.get_custom_objects()[recall.__name__] = recall
tf.keras.utils.get_custom_objects()[f1_score.__name__] = f1_score

# %%
model_6 = tf.keras.models.load_model(os.path.join(model_dir, 'model_6.h5'))

# %%
# Evaluate the model on the test set
test_loss, test_accuracy, test_precision, test_recall, test_f1_score = model_6.evaluate(test_sequences_padded, test_labels)

# Print the test loss and accuracy
print('Test loss:', test_loss)
print('Test accuracy:', test_accuracy)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test f1_score:', test_f1_score)
# Out:
# 28/28 [==============================] - 1s 9ms/step - loss: 0.6191 - accuracy: 0.9311 - precision: 0.9493 - recall: 0.9272 - f1_score: 0.9381
# Test loss: 0.6190772652626038
# Test accuracy: 0.9310932159423828
# Test precision: 0.9492955207824707
# Test recall: 0.9271875023841858
# Test f1_score: 0.9381080865859985

# %%
predict(
    "The patient underwent an electrophysiologic study with mapping of the accessory pathway, followed by radiofrequency ablation (interruption of the pathway using the heat generated by electromagnetic waves at the tip of an ablation catheter).",
    model_6, 
    index_to_label,
    acronyms_to_entities, 
    MAX_LENGTH
)
# Out:
# 2023-04-16 14:01:24.280024: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 1/1 [==============================] - 0s 365ms/step
# Predicted Named Entities:
# patient: O
# underwent: O
# electrophysiologic: Diagnostic_procedure
# study: Diagnostic_procedure
# mapping: Diagnostic_procedure
# accessory: Biological_structure
# pathway: Detailed_description
# followed: Detailed_description
# radiofrequency: Therapeutic_procedure
# ablation: O
# interruption: O
# pathway: O
# using: O
# heat: O
# generated: Therapeutic_procedure
# electromagnetic: O
# waves: O
# tip: O
# ablation: O
# catheter: O
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The patient underwent an
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     electrophysiologic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Diagnostic_procedure</span>
# </mark>
#
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     study
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Diagnostic_procedure</span>
# </mark>
#  with
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mapping
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Diagnostic_procedure</span>
# </mark>
#  of the
# <mark class="entity" style="background: #9ddfd3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     accessory
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Biological_structure</span>
# </mark>
#
# <mark class="entity" style="background: #ffb347; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pathway
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Detailed_description</span>
# </mark>
# ,
# <mark class="entity" style="background: #ffb347; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     followed
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Detailed_description</span>
# </mark>
#  by
# <mark class="entity" style="background: #e6ccb2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     radiofrequency
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Therapeutic_procedure</span>
# </mark>
#  ablation (interruption of the pathway using the heat
# <mark class="entity" style="background: #e6ccb2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     generated
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Therapeutic_procedure</span>
# </mark>
#  by electromagnetic waves at the tip of an ablation catheter).</div></span>

# %%
predict(
    "A 57-year-old man presented to the emergency department with a 2-day history of worsening shortness of breath and chest pain. He reported no recent travel or sick contacts. His medical history was significant for hypertension, dyslipidemia, and type 2 diabetes mellitus. On examination, he was tachycardic and tachypneic, with oxygen saturation of 88% on room air. Chest radiography revealed bilateral opacities consistent with pulmonary edema. The patient was admitted to the intensive care unit for management of acute decompensated heart failure. He was started on intravenous diuretics and inotropic support with dobutamine. Over the next several days, his symptoms improved and he was discharged to home with instructions to follow up with his primary care provider in 1 week.",
    model_6, 
    index_to_label,
    acronyms_to_entities, 
    MAX_LENGTH
)
# Out:
# 1/1 [==============================] - 0s 325ms/step
# Predicted Named Entities:
# 57: Age
# year: Age
# old: Age
# man: Sex
# presented: Personal_background
# emergency: Nonbiological_location
# department: Nonbiological_location
# 2: Nonbiological_location
# day: History
# history: Sign_symptom
# worsening: Sign_symptom
# shortness: Biological_structure
# breath: Sign_symptom
# chest: History
# pain: History
# reported: History
# recent: History
# travel: History
# sick: History
# contacts: History
# medical: History
# history: History
# significant: History
# hypertension: History
# dyslipidemia: History
# type: Sign_symptom
# 2: Sign_symptom
# diabetes: Biological_structure
# mellitus: Diagnostic_procedure
# examination: Detailed_description
# tachycardic: Detailed_description
# tachypneic: Detailed_description
# oxygen: Biological_structure
# saturation: Diagnostic_procedure
# 88: Lab_value
# room: O
# air: Biological_structure
# chest: Detailed_description
# radiography: O
# revealed: Nonbiological_location
# bilateral: Nonbiological_location
# opacities: Nonbiological_location
# consistent: O
# pulmonary: Detailed_description
# edema: Detailed_description
# patient: Detailed_description
# admitted: Therapeutic_procedure
# intensive: Medication
# care: Therapeutic_procedure
# unit: Therapeutic_procedure
# management: Dosage
# acute: Dosage
# decompensated: Dosage
# heart: O
# failure: Medication
# started: Medication
# intravenous: Duration
# diuretics: Duration
# inotropic: O
# support: O
# dobutamine: O
# next: O
# several: O
# days: O
# symptoms: O
# improved: O
# discharged: O
# home: O
# instructions: O
# follow: O
# primary: O
# care: O
# provider: O
# 1: O
# week: O
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     57
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# -
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# -
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
#
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     man
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sex</span>
# </mark>
#
# <mark class="entity" style="background: #a0ced9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     presented
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Personal_background</span>
# </mark>
#  to the
# <mark class="entity" style="background: #f7a399; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     emergency
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nonbiological_location</span>
# </mark>
#
# <mark class="entity" style="background: #f7a399; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     department
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nonbiological_location</span>
# </mark>
#  with a
# <mark class="entity" style="background: #f7a399; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nonbiological_location</span>
# </mark>
# -
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     history
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#  of
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     worsening
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#
# <mark class="entity" style="background: #9ddfd3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     shortness
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Biological_structure</span>
# </mark>
#  of
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     breath
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#  and
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chest
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# . He
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     reported
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  no
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     recent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     travel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  or
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sick
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     contacts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# . His
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     medical
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     history
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  was
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     significant
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  for
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hypertension
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# ,
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dyslipidemia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# , and
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     type

# %%
predict_multi_line_text(
    
    "A 57-year-old man presented to the emergency department with a 2-day history of worsening shortness of breath and chest pain. He reported no recent travel or sick contacts. His medical history was significant for hypertension, dyslipidemia, and type 2 diabetes mellitus. On examination, he was tachycardic and tachypneic, with oxygen saturation of 88% on room air. Chest radiography revealed bilateral opacities consistent with pulmonary edema. The patient was admitted to the intensive care unit for management of acute decompensated heart failure. He was started on intravenous diuretics and inotropic support with dobutamine. Over the next several days, his symptoms improved and he was discharged to home with instructions to follow up with his primary care provider in 1 week.",
    model_6, 
    index_to_label,
    acronyms_to_entities, 
    MAX_LENGTH
    
)
# Out:
# 1/1 [==============================] - 0s 14ms/step
# Predicted Named Entities:
# 57: Age
# year: Age
# old: Age
# man: Sex
# presented: Personal_background
# emergency: Nonbiological_location
# department: Nonbiological_location
# 2: Nonbiological_location
# day: O
# history: Sign_symptom
# worsening: Sign_symptom
# shortness: Biological_structure
# breath: Sign_symptom
# chest: O
# pain: O
#
#
#
#
# reported: Clinical_event
# recent: History
# travel: History
# sick: O
# contacts: O
#
#
#
#
# medical: O
# history: O
# significant: History
# hypertension: History
# dyslipidemia: History
# type: History
# 2: History
# diabetes: History
# mellitus: History
#
#
#
#
# examination: Diagnostic_procedure
# tachycardic: Sign_symptom
# tachypneic: Diagnostic_procedure
# oxygen: Diagnostic_procedure
# saturation: Lab_value
# 88: Detailed_description
# room: Detailed_description
# air: O
#
#
#
#
# chest: Biological_structure
# radiography: Diagnostic_procedure
# revealed: Lab_value
# bilateral: O
# opacities: Biological_structure
# consistent: Sign_symptom
# pulmonary: O
# edema: O
#
#
#
#
# patient: O
# admitted: Nonbiological_location
# intensive: Nonbiological_location
# care: Nonbiological_location
# unit: O
# management: Detailed_description
# acute: Detailed_description
# decompensated: Distance
# heart: O
# failure: O
#
#
#
#
# started: Therapeutic_procedure
# intravenous: Medication
# diuretics: Therapeutic_procedure
# inotropic: Therapeutic_procedure
# support: O
# dobutamine: O
#
#
#
#
# next: Distance
# several: Duration
# days: Nonbiological_location
# symptoms: Clinical_event
# improved: Nonbiological_location
# discharged: Distance
# home: Nonbiological_location
# instructions: Duration
# follow: O
# primary: O
# care: O
# provider: O
# 1: O
# week: O
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     57
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# -
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# -
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
#
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     man
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sex</span>
# </mark>
#
# <mark class="entity" style="background: #a0ced9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     presented
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Personal_background</span>
# </mark>
#  to the
# <mark class="entity" style="background: #f7a399; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     emergency
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nonbiological_location</span>
# </mark>
#
# <mark class="entity" style="background: #f7a399; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     department
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nonbiological_location</span>
# </mark>
#  with a
# <mark class="entity" style="background: #f7a399; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nonbiological_location</span>
# </mark>
# -day
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     history
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#  of
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     worsening
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#
# <mark class="entity" style="background: #9ddfd3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     shortness
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Biological_structure</span>
# </mark>
#  of
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     breath
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#  and chest pain. He
# <mark class="entity" style="background: #77c5d5; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     reported
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Clinical_event</span>
# </mark>
#  no
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     recent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     travel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  or sick contacts. His medical history was
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     significant
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  for
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hypertension
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# ,
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dyslipidemia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# , and
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     type
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     diabetes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mellitus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# . On
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     examination
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Diagnostic_procedure</span>
# </mark>
# , he was
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tachycardic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#  and
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tachypneic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Diagnostic_procedure</span>
# </mark>
# , with
# <mark class="entity" st
