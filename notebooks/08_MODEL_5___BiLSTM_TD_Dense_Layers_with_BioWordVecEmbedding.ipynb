# %%
import os
import re
import pickle
import pandas as pd
import numpy as np
import gensim
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import classification_report

# %%
import sys
sys.path.append('../scripts')
from utils import predict, predict_multi_line_text, load_data

sys.path.append('../')
from config import entity_to_acronyms, acronyms_to_entities
# Out:
# [nltk_data] Error loading punkt: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1131)>
# [nltk_data] Error loading stopwords: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1131)>

# %%
# from importlib import reload

# import utils
# reload(utils)

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input, Embedding, Bidirectional, LSTM, Dense

# %%
from config import entity_to_acronyms, acronyms_to_entities

# %%
data_dir = '../data'
model_dir = '../models'

# %%
(train_sequences_padded, train_labels), (val_sequences_padded, val_labels), (test_sequences_padded, test_labels), label_to_index, index_to_label = load_data(data_dir)

# %%
if train_sequences_padded.shape[1] != train_labels.shape[1]:
    print('Sequence length mismatch')

# %%
# Load the tokenizer from file
with open('../data/tokenizer.pickle', 'rb') as handle:
    tokenizer = pickle.load(handle)

# %% [markdown]
# ## Model parameters

# %%
INPUT_DIM = len(tokenizer.word_index)+1
EMBEDDING_DIM = 200
NUM_CLASSES = len(label_to_index)
MAX_LENGTH = train_sequences_padded.shape[1]

LSTM_UNITS = 64
DENSE_UNITS = 64

DROPOUT_RATE = 0.2
BATCH_SIZE = 32
EPOCHS = 20

# %% [markdown]
# ## Load the BioWordVec vectors

# %%
path_to_vectors = os.path.join(data_dir, 'embedding_vectors', 'BioWordVec_PubMed_MIMICIII_d200.vec.bin')
biowv = gensim.models.KeyedVectors.load_word2vec_format(path_to_vectors, binary=True)

# %% [markdown]
# ## Create embedding layer using the BioWordVec vectors

# %%
embedding_matrix = np.zeros((INPUT_DIM, EMBEDDING_DIM))
for word, i in tokenizer.word_index.items():
    if word in biowv.index_to_key:
        embedding_matrix[i] = biowv[word]
        
embedding_layer = tf.keras.layers.Embedding(
    INPUT_DIM,
    EMBEDDING_DIM,
    embeddings_initializer=tf.keras.initializers.Constant(embedding_matrix),
    input_length=MAX_LENGTH,
    trainable=False
)

# %% [markdown]
# ## Building Model

# %%
from keras import backend as K

def precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    _precision = true_positives / (predicted_positives + K.epsilon())
    return _precision

def recall(y_true, y_pred):
    """Compute recall metric"""
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

def f1_score(y_true, y_pred):
    """Compute f1-score metric"""
    _precision = precision(y_true, y_pred)
    _recall = recall(y_true, y_pred)
    f1_score = 2 * ((_precision * _recall) / (_precision + _recall + K.epsilon()))
    return f1_score

# %%
import tensorflow as tf

# Define the model architecture
model = tf.keras.models.Sequential([
    
    # Add an embedding layer to learn the representations of words in the input text
    embedding_layer,
    
    # Add a Bidirectional LSTM layer to capture contextual information from both directions
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(units=LSTM_UNITS, return_sequences=True)),
    
    # Add a TimeDistributed dense layer to apply a dense layer to each time step of the LSTM output
    tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(units=DENSE_UNITS, activation='relu')),
    
    # Add a dropout layer to reduce overfitting
    tf.keras.layers.Dropout(rate=DROPOUT_RATE),
    
    # Add a TimeDistributed dense layer to apply a dense layer to each time step of the previous dense layer output
    tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(units=NUM_CLASSES, activation='softmax'))
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy', precision, recall, f1_score])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 200)          1393800
#
#  bidirectional (Bidirectiona  (None, 100, 128)         135680
#  l)
#
#  time_distributed (TimeDistr  (None, 100, 64)          8256
#  ibuted)
#
#  dropout (Dropout)           (None, 100, 64)           0
#
#  time_distributed_1 (TimeDis  (None, 100, 79)          5135
#  tributed)
#
# =================================================================
# Total params: 1,542,871
# Trainable params: 149,071
# Non-trainable params: 1,393,800
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    train_sequences_padded, 
    train_labels, 
    epochs=EPOCHS, 
    validation_data=(val_sequences_padded, val_labels)
)
# Out:
# Epoch 1/20
# 2023-04-09 12:30:14.467425: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 95/95 [==============================] - 7s 47ms/step - loss: 1.1151 - accuracy: 0.8923 - precision: 0.8013 - recall: 0.7002 - f1_score: 0.7403 - val_loss: 0.3775 - val_accuracy: 0.9139 - val_precision: 0.9856 - val_recall: 0.8915 - val_f1_score: 0.9362
# Epoch 2/20
# 95/95 [==============================] - 5s 48ms/step - loss: 0.3421 - accuracy: 0.9141 - precision: 0.9920 - recall: 0.8866 - f1_score: 0.9363 - val_loss: 0.3342 - val_accuracy: 0.9229 - val_precision: 0.9846 - val_recall: 0.8964 - val_f1_score: 0.9384
# Epoch 3/20
# 95/95 [==============================] - 4s 47ms/step - loss: 0.2865 - accuracy: 0.9232 - precision: 0.9897 - recall: 0.8938 - f1_score: 0.9393 - val_loss: 0.3162 - val_accuracy: 0.9263 - val_precision: 0.9787 - val_recall: 0.9032 - val_f1_score: 0.9394
# Epoch 4/20
# 95/95 [==============================] - 4s 47ms/step - loss: 0.2547 - accuracy: 0.9290 - precision: 0.9869 - recall: 0.9004 - f1_score: 0.9416 - val_loss: 0.3017 - val_accuracy: 0.9295 - val_precision: 0.9755 - val_recall: 0.9088 - val_f1_score: 0.9410
# Epoch 5/20
# 95/95 [==============================] - 5s 50ms/step - loss: 0.2337 - accuracy: 0.9341 - precision: 0.9852 - recall: 0.9063 - f1_score: 0.9441 - val_loss: 0.2886 - val_accuracy: 0.9323 - val_precision: 0.9770 - val_recall: 0.9100 - val_f1_score: 0.9423
# Epoch 6/20
# 95/95 [==============================] - 5s 54ms/step - loss: 0.2171 - accuracy: 0.9379 - precision: 0.9845 - recall: 0.9115 - f1_score: 0.9465 - val_loss: 0.2877 - val_accuracy: 0.9340 - val_precision: 0.9707 - val_recall: 0.9167 - val_f1_score: 0.9429
# Epoch 7/20
# 95/95 [==============================] - 5s 54ms/step - loss: 0.2059 - accuracy: 0.9410 - precision: 0.9837 - recall: 0.9162 - f1_score: 0.9487 - val_loss: 0.2892 - val_accuracy: 0.9346 - val_precision: 0.9692 - val_recall: 0.9195 - val_f1_score: 0.9437
# Epoch 8/20
# 95/95 [==============================] - 5s 56ms/step - loss: 0.1962 - accuracy: 0.9434 - precision: 0.9831 - recall: 0.9198 - f1_score: 0.9504 - val_loss: 0.2807 - val_accuracy: 0.9358 - val_precision: 0.9703 - val_recall: 0.9201 - val_f1_score: 0.9445
# Epoch 9/20
# 95/95 [==============================] - 5s 58ms/step - loss: 0.1898 - accuracy: 0.9451 - precision: 0.9832 - recall: 0.9225 - f1_score: 0.9519 - val_loss: 0.2818 - val_accuracy: 0.9370 - val_precision: 0.9689 - val_recall: 0.9218 - val_f1_score: 0.9447
# Epoch 10/20
# 95/95 [==============================] - 5s 53ms/step - loss: 0.1815 - accuracy: 0.9470 - precision: 0.9827 - recall: 0.9257 - f1_score: 0.9533 - val_loss: 0.2813 - val_accuracy: 0.9379 - val_precision: 0.9669 - val_recall: 0.9239 - val_f1_score: 0.9449
# Epoch 11/20
# 95/95 [==============================] - 5s 56ms/step - loss: 0.1756 - accuracy: 0.9485 - precision: 0.9826 - recall: 0.9278 - f1_score: 0.9544 - val_loss: 0.2827 - val_accuracy: 0.9382 - val_precision: 0.9670 - val_recall: 0.9257 - val_f1_score: 0.9459
# Epoch 12/20
# 95/95 [==============================] - 5s 53ms/step - loss: 0.1697 - accuracy: 0.9502 - precision: 0.9828 - recall: 0.9306 - f1_score: 0.9559 - val_loss: 0.2853 - val_accuracy: 0.9391 - val_precision: 0.9669 - val_recall: 0.9259 - val_f1_score: 0.9459
# Epoch 13/20
# 95/95 [==============================] - 5s 54ms/step - loss: 0.1644 - accuracy: 0.9518 - precision: 0.9829 - recall: 0.9328 - f1_score: 0.9572 - val_loss: 0.2780 - val_accuracy: 0.9395 - val_precision: 0.9659 - val_recall: 0.9275 - val_f1_score: 0.9463
# Epoch 14/20
# 95/95 [==============================] - 5s 57ms/step - loss: 0.1586 - accuracy: 0.9533 - precision: 0.9827 - recall: 0.9351 - f1_score: 0.9583 - val_loss: 0.2867 - val_accuracy: 0.9392 - val_precision: 0.9658 - val_recall: 0.9281 - val_f1_score: 0.9466
# Epoch 15/20
# 95/95 [==============================] - 5s 51ms/step - loss: 0.1544 - accuracy: 0.9544 - precision: 0.9829 - recall: 0.9368 - f1_score: 0.9593 - val_loss: 0.2839 - val_accuracy: 0.9398 - val_precision: 0.9649 - val_recall: 0.9286 - val_f1_score: 0.9464
# Epoch 16/20
# 95/95 [==============================] - 4s 42ms/step - loss: 0.1501 - accuracy: 0.9558 - precision: 0.9828 - recall: 0.9386 - f1_score: 0.9602 - val_loss: 0.2834 - val_accuracy: 0.9406 - val_precision: 0.9649 - val_recall: 0.9294 - val_f1_score: 0.9468
# Epoch 17/20
# 95/95 [==============================] - 4s 43ms/step - loss: 0.1448 - accuracy: 0.9570 - precision: 0.9828 - recall: 0.9406 - f1_score: 0.9612 - val_loss: 0.2813 - val_accuracy: 0.9406 - val_precision: 0.9651 - val_recall: 0.9296 - val_f1_score: 0.9470
# Epoch 18/20
# 95/95 [==============================] - 4s 44ms/step - loss: 0.1407 - accuracy: 0.9582 - precision: 0.9832 - recall: 0.9422 - f1_score: 0.9622 - val_loss: 0.2837 - val_accuracy: 0.9407 - val_precision: 0.9639 - val_recall: 0.9310 - val_f1_score: 0.9472
# Epoch 19/20
# 95/95 [==============================] - 4s 44ms/step - loss: 0.1361 - accuracy: 0.9597 - precision: 0.9833 - recall: 0.9439 - f1_score: 0.9632 - val_loss: 0.2915 - val_accuracy: 0.9410 - val_precision: 0.9625 - val_recall: 0.9316 - val_f1_score: 0.9468
# Epoch 20/20
# 95/95 [==============================] - 4s 46ms/step - loss: 0.1332 - accuracy: 0.9602 - precision: 0.9831 - recall: 0.9448 - f1_score: 0.9636 - val_loss: 0.2905 - val_accuracy: 0.9409 - val_precision: 0.9636 - val_recall: 0.9316 - val_f1_score: 0.9473

# %%
import matplotlib.pyplot as plt

def plot_graphs(history):
    fig, axs = plt.subplots(2, 2, figsize=(12, 8))
    
    axs[0, 0].plot(history.history['accuracy'])
    axs[0, 0].plot(history.history['val_accuracy'])
    axs[0, 0].set_title('Model Accuracy')
    axs[0, 0].set_ylabel('Accuracy')
    axs[0, 0].legend(['train', 'val'], loc='best')
    
    axs[0, 1].plot(history.history['loss'])
    axs[0, 1].plot(history.history['val_loss'])
    axs[0, 1].set_title('Model Loss')
    axs[0, 1].set_ylabel('Loss')
    axs[0, 1].legend(['train', 'val'], loc='best')
    
    axs[1, 0].plot(history.history['recall'])
    axs[1, 0].plot(history.history['val_recall'])
    axs[1, 0].set_title('Model Recall')
    axs[1, 0].set_ylabel('Recall')
    axs[1, 0].legend(['train', 'val'], loc='best')
    
    axs[1, 1].plot(history.history['f1_score'])
    axs[1, 1].plot(history.history['val_f1_score'])
    axs[1, 1].set_title('Model F1 Score')
    axs[1, 1].set_ylabel('F1 Score')
    axs[1, 1].legend(['train', 'val'], loc='best')
    
    plt.tight_layout()
    plt.show()

# %%
# Plot the training history
plot_graphs(history)

# %%
from sklearn.metrics import classification_report

# Get the model predictions
y_pred = model.predict(test_sequences_padded)

# Convert the predictions from one-hot encoded format to the label format
y_pred_labels = np.argmax(y_pred, axis=2)
test_labels_labels = np.argmax(test_labels, axis=2)

# Print the classification report
print(classification_report(test_labels_labels.reshape(-1), y_pred_labels.reshape(-1), zero_division=0))
# Out:
# 28/28 [==============================] - 2s 16ms/step
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        15
#            2       0.56      0.54      0.55        37
#            3       0.89      0.89      0.89        36
#            4       0.33      0.25      0.29         4
#            6       0.50      0.47      0.49       467
#            7       0.72      0.58      0.64       100
#            8       0.40      0.38      0.39        16
#            9       0.40      0.04      0.07        56
#           10       0.36      0.49      0.42        97
#           11       0.36      0.26      0.30       478
#           12       0.61      0.47      0.53       684
#           13       0.36      0.31      0.34       236
#           14       0.53      0.43      0.47        65
#           15       0.36      0.27      0.31        45
#           16       0.00      0.00      0.00        16
#           17       1.00      0.18      0.31        11
#           19       0.42      0.09      0.15        55
#           20       0.42      0.36      0.39       465
#           21       0.00      0.00      0.00         2
#           22       0.58      0.51      0.54       143
#           23       0.62      0.59      0.60        49
#           24       0.00      0.00      0.00         6
#           25       0.00      0.00      0.00         2
#           26       0.00      0.00      0.00         2
#           27       0.00      0.00      0.00         3
#           28       0.75      0.38      0.50         8
#           29       0.00      0.00      0.00        11
#           30       0.65      0.45      0.53        74
#           31       0.78      0.91      0.84        32
#           32       0.00      0.00      0.00         7
#           33       0.45      0.41      0.43       558
#           34       0.00      0.00      0.00        12
#           35       0.00      0.00      0.00        10
#           36       0.34      0.24      0.28       163
#           37       0.00      0.00      0.00        10
#           38       0.00      0.00      0.00         4
#           40       0.00      0.00      0.00        11
#           41       0.00      0.00      0.00         7
#           42       0.91      0.90      0.91        71
#           43       0.29      0.18      0.22        11
#           45       0.51      0.57      0.54       505
#           46       0.00      0.00      0.00         1
#           47       0.00      0.00      0.00        10
#           48       0.00      0.00      0.00        15
#           49       0.47      0.60      0.52       161
#           50       0.27      0.21      0.24       460
#           51       0.62      0.60      0.61       924
#           52       0.39      0.32      0.35       199
#           53       0.55      0.39      0.46       107
#           54       0.31      0.19      0.23        59
#           55       0.19      0.06      0.10        78
#           56       0.00      0.00      0.00        13
#           58       0.41      0.34      0.37       188
#           59       0.44      0.26      0.33       385
#           60       0.00      0.00      0.00         2
#           61       0.62      0.37      0.46       119
#           62       0.62      0.52      0.57        48
#           63       0.00      0.00      0.00         9
#           64       0.00      0.00      0.00         4
#           65       0.00      0.00      0.00         2
#           66       0.00      0.00      0.00         1
#           67       0.00      0.00      0.00         3
#           68       0.00      0.00      0.00         9
#           69       0.00      0.00      0.00         9
#           70       0.00      0.00      0.00         1
#           71       0.34      0.22      0.27       354
#           72       0.00      0.00      0.00         3
#           73       0.00      0.00      0.00         6
#           74       0.37      0.22      0.28       127
#           75       0.00      0.00      0.00         8
#           76       0.30      0.43      0.35         7
#           78       0.97      0.99      0.98     79004
#
#     accuracy                           0.94     86900
#    macro avg       0.29      0.23      0.25     86900
# weighted avg       0.93      0.94      0.93     86900

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

report = classification_report(test_labels_labels.reshape(-1), y_pred_labels.reshape(-1), zero_division=0, output_dict=True)
plt.subplots(figsize=(20, 20))
sns.heatmap(pd.DataFrame(report).iloc[:-1, :].T, annot=True, cmap='Blues', fmt='.2f')
plt.show()

# %% [markdown]
# In the case of NER task, all three metrics - precision, recall, and F1 score - are important.
#
# * Precision measures the proportion of predicted entities that are actually correct. In NER, precision means how many of the predicted named entities are actually true named entities.
#
# * Recall measures the proportion of actual entities that are correctly identified by the model. In NER, recall means how many true named entities are correctly identified by the model.
#
# * F1 score is the harmonic mean of precision and recall. It is a balanced metric that takes into account both precision and recall. F1 score is commonly used in NER evaluation as it takes into account both false positives and false negatives.
#
# A high precision score means that the model is making very few false predictions, while a high recall score means that the model is identifying a high proportion of the true named entities. A high F1 score indicates that the model is both precise and recallful.

# %% [markdown]
# ## Save the model as an .h5 file

# %%
model.save(os.path.join(model_dir, 'model_5.h5'))

# %% [markdown]
# ## Load the model

# %%
# Register the custom metric function
tf.keras.utils.get_custom_objects()[precision.__name__] = precision
tf.keras.utils.get_custom_objects()[recall.__name__] = recall
tf.keras.utils.get_custom_objects()[f1_score.__name__] = f1_score

# %%
model_5 = tf.keras.models.load_model(os.path.join(model_dir, 'model_5.h5'))

# %%
# Evaluate the model on the test set
test_loss, test_accuracy, test_precision, test_recall, test_f1_score = model_5.evaluate(test_sequences_padded, test_labels)

# Print the test loss and accuracy
print('Test loss:', test_loss)
print('Test accuracy:', test_accuracy)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test f1_score:', test_f1_score)
# Out:
# 28/28 [==============================] - 1s 16ms/step - loss: 0.3109 - accuracy: 0.9379 - precision: 0.9616 - recall: 0.9291 - f1_score: 0.9451
# Test loss: 0.3109476864337921
# Test accuracy: 0.9378595948219299
# Test precision: 0.9616339802742004
# Test recall: 0.9290780425071716
# Test f1_score: 0.9450715780258179

# %%
predict(
    "The patient underwent an electrophysiologic study with mapping of the accessory pathway, followed by radiofrequency ablation (interruption of the pathway using the heat generated by electromagnetic waves at the tip of an ablation catheter).",
    model_5, 
    index_to_label,
    acronyms_to_entities, 
    MAX_LENGTH
)
# Out:
# 2023-04-16 13:58:19.200993: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 1/1 [==============================] - 0s 453ms/step
# Predicted Named Entities:
# patient: O
# underwent: O
# electrophysiologic: Diagnostic_procedure
# study: Diagnostic_procedure
# mapping: Detailed_description
# accessory: Detailed_description
# pathway: Detailed_description
# followed: Detailed_description
# radiofrequency: Therapeutic_procedure
# ablation: O
# interruption: Detailed_description
# pathway: Detailed_description
# using: Detailed_description
# heat: Detailed_description
# generated: Therapeutic_procedure
# electromagnetic: O
# waves: O
# tip: O
# ablation: O
# catheter: O
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The patient underwent an
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     electrophysiologic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Diagnostic_procedure</span>
# </mark>
#
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     study
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Diagnostic_procedure</span>
# </mark>
#  with
# <mark class="entity" style="background: #ffb347; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mapping
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Detailed_description</span>
# </mark>
#  of the
# <mark class="entity" style="background: #ffb347; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     accessory
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Detailed_description</span>
# </mark>
#
# <mark class="entity" style="background: #ffb347; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pathway
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Detailed_description</span>
# </mark>
# ,
# <mark class="entity" style="background: #ffb347; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     followed
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Detailed_description</span>
# </mark>
#  by
# <mark class="entity" style="background: #e6ccb2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     radiofrequency
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Therapeutic_procedure</span>
# </mark>
#  ablation (
# <mark class="entity" style="background: #ffb347; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     interruption
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Detailed_description</span>
# </mark>
#  of the
# <mark class="entity" style="background: #ffb347; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pathway
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Detailed_description</span>
# </mark>
#
# <mark class="entity" style="background: #ffb347; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     using
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Detailed_description</span>
# </mark>
#  the
# <mark class="entity" style="background: #ffb347; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     heat
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Detailed_description</span>
# </mark>
#
# <mark class="entity" style="background: #e6ccb2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     generated
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Therapeutic_procedure</span>
# </mark>
#  by electromagnetic waves at the tip of an ablation catheter).</div></span>

# %%
predict(
    "A 57-year-old man presented to the emergency department with a 2-day history of worsening shortness of breath and chest pain. He reported no recent travel or sick contacts. His medical history was significant for hypertension, dyslipidemia, and type 2 diabetes mellitus. On examination, he was tachycardic and tachypneic, with oxygen saturation of 88% on room air. Chest radiography revealed bilateral opacities consistent with pulmonary edema. The patient was admitted to the intensive care unit for management of acute decompensated heart failure. He was started on intravenous diuretics and inotropic support with dobutamine. Over the next several days, his symptoms improved and he was discharged to home with instructions to follow up with his primary care provider in 1 week.",
    model_5, 
    index_to_label,
    acronyms_to_entities, 
    MAX_LENGTH
)
# Out:
# 1/1 [==============================] - 0s 325ms/step
# Predicted Named Entities:
# 57: Age
# year: Age
# old: Age
# man: Sex
# presented: Nonbiological_location
# emergency: Nonbiological_location
# department: Duration
# 2: Duration
# day: O
# history: Sign_symptom
# worsening: Sign_symptom
# shortness: Biological_structure
# breath: Sign_symptom
# chest: History
# pain: History
# reported: History
# recent: O
# travel: O
# sick: O
# contacts: History
# medical: History
# history: History
# significant: History
# hypertension: History
# dyslipidemia: History
# type: O
# 2: O
# diabetes: Diagnostic_procedure
# mellitus: Diagnostic_procedure
# examination: Lab_value
# tachycardic: Detailed_description
# tachypneic: Detailed_description
# oxygen: Biological_structure
# saturation: Diagnostic_procedure
# 88: Detailed_description
# room: O
# air: Biological_structure
# chest: Sign_symptom
# radiography: O
# revealed: Nonbiological_location
# bilateral: Nonbiological_location
# opacities: Nonbiological_location
# consistent: O
# pulmonary: Detailed_description
# edema: Therapeutic_procedure
# patient: Distance
# admitted: Administration
# intensive: Medication
# care: Medication
# unit: Medication
# management: O
# acute: O
# decompensated: Nonbiological_location
# heart: Clinical_event
# failure: O
# started: Nonbiological_location
# intravenous: Duration
# diuretics: Duration
# inotropic: O
# support: O
# dobutamine: O
# next: O
# several: O
# days: O
# symptoms: O
# improved: O
# discharged: O
# home: O
# instructions: O
# follow: O
# primary: O
# care: O
# provider: O
# 1: O
# week: O
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     57
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# -
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# -
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
#
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     man
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sex</span>
# </mark>
#
# <mark class="entity" style="background: #f7a399; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     presented
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nonbiological_location</span>
# </mark>
#  to the
# <mark class="entity" style="background: #f7a399; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     emergency
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nonbiological_location</span>
# </mark>
#
# <mark class="entity" style="background: #ffdfba; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     department
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Duration</span>
# </mark>
#  with a
# <mark class="entity" style="background: #ffdfba; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Duration</span>
# </mark>
# -day
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     history
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#  of
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     worsening
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#
# <mark class="entity" style="background: #9ddfd3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     shortness
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Biological_structure</span>
# </mark>
#  of
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     breath
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#  and
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chest
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# . He
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     reported
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  no recent travel or sick
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     contacts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# . His
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     medical
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     history
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  was
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     significant
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  for
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hypertension
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# ,
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dyslipidemia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# , and type 2
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     diabetes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Diagnostic_procedure</span>
# </mark>
#
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mellitus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Diagnostic_procedure</span>
# </mark>
# . On
# <mark class="entity" style="background: #f4b3c2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     examination
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Lab_value</span>
# </mark>
# , he was
# <mark class="entity" style="background: #ffb347; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tachycardic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Detailed_description</span>
# </mark>
#  and
# <mark class="entity" style="background: #ffb347; padding: 0.45

# %%
predict_multi_line_text(
    
    "A 57-year-old man presented to the emergency department with a 2-day history of worsening shortness of breath and chest pain. He reported no recent travel or sick contacts. His medical history was significant for hypertension, dyslipidemia, and type 2 diabetes mellitus. On examination, he was tachycardic and tachypneic, with oxygen saturation of 88% on room air. Chest radiography revealed bilateral opacities consistent with pulmonary edema. The patient was admitted to the intensive care unit for management of acute decompensated heart failure. He was started on intravenous diuretics and inotropic support with dobutamine. Over the next several days, his symptoms improved and he was discharged to home with instructions to follow up with his primary care provider in 1 week.",
    model_5, 
    index_to_label,
    acronyms_to_entities, 
    MAX_LENGTH
    
)
# Out:
# 1/1 [==============================] - 0s 15ms/step
# Predicted Named Entities:
# 57: Age
# year: Age
# old: Age
# man: Sex
# presented: Nonbiological_location
# emergency: Nonbiological_location
# department: Duration
# 2: Duration
# day: O
# history: Sign_symptom
# worsening: Sign_symptom
# shortness: Biological_structure
# breath: Sign_symptom
# chest: O
# pain: O
#
#
#
#
# reported: O
# recent: O
# travel: History
# sick: O
# contacts: O
#
#
#
#
# medical: O
# history: O
# significant: O
# hypertension: History
# dyslipidemia: History
# type: History
# 2: History
# diabetes: History
# mellitus: History
#
#
#
#
# examination: Diagnostic_procedure
# tachycardic: Sign_symptom
# tachypneic: Diagnostic_procedure
# oxygen: Diagnostic_procedure
# saturation: Lab_value
# 88: Detailed_description
# room: Detailed_description
# air: O
#
#
#
#
# chest: Biological_structure
# radiography: Diagnostic_procedure
# revealed: Detailed_description
# bilateral: O
# opacities: Biological_structure
# consistent: Sign_symptom
# pulmonary: O
# edema: O
#
#
#
#
# patient: O
# admitted: Nonbiological_location
# intensive: Nonbiological_location
# care: Nonbiological_location
# unit: O
# management: Detailed_description
# acute: Distance
# decompensated: Distance
# heart: O
# failure: O
#
#
#
#
# started: Administration
# intravenous: Medication
# diuretics: O
# inotropic: Medication
# support: O
# dobutamine: O
#
#
#
#
# next: O
# several: O
# days: Nonbiological_location
# symptoms: Clinical_event
# improved: O
# discharged: Nonbiological_location
# home: Duration
# instructions: Duration
# follow: O
# primary: O
# care: O
# provider: O
# 1: O
# week: O
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     57
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# -
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# -
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
#
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     man
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sex</span>
# </mark>
#
# <mark class="entity" style="background: #f7a399; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     presented
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nonbiological_location</span>
# </mark>
#  to the
# <mark class="entity" style="background: #f7a399; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     emergency
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nonbiological_location</span>
# </mark>
#
# <mark class="entity" style="background: #ffdfba; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     department
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Duration</span>
# </mark>
#  with a
# <mark class="entity" style="background: #ffdfba; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Duration</span>
# </mark>
# -day
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     history
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#  of
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     worsening
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#
# <mark class="entity" style="background: #9ddfd3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     shortness
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Biological_structure</span>
# </mark>
#  of
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     breath
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#  and chest pain. He reported no recent
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     travel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  or sick contacts. His medical history was significant for
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hypertension
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# ,
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dyslipidemia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# , and
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     type
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     diabetes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mellitus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# . On
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     examination
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Diagnostic_procedure</span>
# </mark>
# , he was
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tachycardic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#  and
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tachypneic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Diagnostic_procedure</span>
# </mark>
# , with
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     oxygen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Diagnostic_procedure</span>
# </mark>
#
# <mark class="entity" style="background: #f4b3c2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     saturation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Lab_value</span>
# </mark>
#  of
# <mark class="entity" style="background: #ffb347; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     88
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Detailed_description</span>
# </mark>
# % on
