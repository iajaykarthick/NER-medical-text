# %%
import sys
sys.path.append('../scripts')
from predict import NER
# Out:
# [nltk_data] Error loading punkt: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1131)>
# [nltk_data] Error loading stopwords: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1131)>

# %%
NER("model_1",
        "A 57-year-old man presented to the emergency department with a 2-day history of worsening shortness of breath and chest pain. He reported no recent travel or sick contacts. His medical history was significant for hypertension, dyslipidemia, and type 2 diabetes mellitus. On examination, he was tachycardic and tachypneic, with oxygen saturation of 88% on room air. Chest radiography revealed bilateral opacities consistent with pulmonary edema. The patient was admitted to the intensive care unit for management of acute decompensated heart failure. He was started on intravenous diuretics and inotropic support with dobutamine. Over the next several days, his symptoms improved and he was discharged to home with instructions to follow up with his primary care provider in 1 week.")
# Out:
# Model provided:  Bidirectional LSTM Model with single LSTM layer
# 2023-04-09 12:55:49.322630: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 1/1 [==============================] - 1s 500ms/step
# Predicted Named Entities:
# 57: Age
# year: Age
# old: Age
# man: Sex
# presented: Nonbiological_location
# emergency: Nonbiological_location
# department: Duration
# 2: Duration
# day: O
# history: Sign_symptom
# worsening: Sign_symptom
# shortness: Biological_structure
# breath: Sign_symptom
# chest: History
# pain: History
# reported: History
# recent: History
# travel: History
# sick: History
# contacts: History
# medical: History
# history: History
# significant: History
# hypertension: History
# dyslipidemia: History
# type: History
# 2: Sign_symptom
# diabetes: History
# mellitus: Diagnostic_procedure
# examination: O
# tachycardic: Detailed_description
# tachypneic: Detailed_description
# oxygen: Biological_structure
# saturation: Diagnostic_procedure
# 88: Detailed_description
# room: O
# air: Distance
# chest: Distance
# radiography: O
# revealed: Distance
# bilateral: O
# opacities: O
# consistent: O
# pulmonary: Detailed_description
# edema: Distance
# patient: Distance
# admitted: Distance
# intensive: Medication
# care: Therapeutic_procedure
# unit: Medication
# management: Dosage
# acute: Dosage
# decompensated: Dosage
# heart: Clinical_event
# failure: Other_entity
# started: Nonbiological_location
# intravenous: Date
# diuretics: Date
# inotropic: O
# support: O
# dobutamine: O
# next: O
# several: O
# days: O
# symptoms: O
# improved: O
# discharged: O
# home: O
# instructions: O
# follow: O
# primary: O
# care: O
# provider: O
# 1: O
# week: O
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     57
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# -
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# -
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
#
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     man
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sex</span>
# </mark>
#
# <mark class="entity" style="background: #f7a399; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     presented
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nonbiological_location</span>
# </mark>
#  to the
# <mark class="entity" style="background: #f7a399; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     emergency
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nonbiological_location</span>
# </mark>
#
# <mark class="entity" style="background: #ffdfba; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     department
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Duration</span>
# </mark>
#  with a
# <mark class="entity" style="background: #ffdfba; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Duration</span>
# </mark>
# -day
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     history
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#  of
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     worsening
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#
# <mark class="entity" style="background: #9ddfd3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     shortness
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Biological_structure</span>
# </mark>
#  of
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     breath
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#  and
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chest
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# . He
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     reported
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  no
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     recent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     travel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  or
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sick
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     contacts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# . His
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     medical
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     history
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  was
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     significant
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  for
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hypertension
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# ,
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dyslipidemia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# , and
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     type
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size

# %% [markdown]
# ## MODEL 2

# %%
NER("model_2",
        "A 57-year-old man presented to the emergency department with a 2-day history of worsening shortness of breath and chest pain. He reported no recent travel or sick contacts. His medical history was significant for hypertension, dyslipidemia, and type 2 diabetes mellitus. On examination, he was tachycardic and tachypneic, with oxygen saturation of 88% on room air. Chest radiography revealed bilateral opacities consistent with pulmonary edema. The patient was admitted to the intensive care unit for management of acute decompensated heart failure. He was started on intravenous diuretics and inotropic support with dobutamine. Over the next several days, his symptoms improved and he was discharged to home with instructions to follow up with his primary care provider in 1 week.")
# Out:
# Model provided:  Bidirectional LSTM Model with two LSTM layers and one Hidden Dense Layer
# 1/1 [==============================] - 1s 694ms/step
# Predicted Named Entities:
# 57: Age
# year: Age
# old: Age
# man: Sex
# presented: Nonbiological_location
# emergency: Nonbiological_location
# department: History
# 2: Date
# day: O
# history: Sign_symptom
# worsening: Sign_symptom
# shortness: Biological_structure
# breath: Sign_symptom
# chest: O
# pain: Nonbiological_location
# reported: History
# recent: History
# travel: History
# sick: History
# contacts: History
# medical: Nonbiological_location
# history: Nonbiological_location
# significant: History
# hypertension: Nonbiological_location
# dyslipidemia: Nonbiological_location
# type: Nonbiological_location
# 2: Biological_structure
# diabetes: Diagnostic_procedure
# mellitus: Diagnostic_procedure
# examination: Lab_value
# tachycardic: Detailed_description
# tachypneic: Detailed_description
# oxygen: Biological_structure
# saturation: Diagnostic_procedure
# 88: Detailed_description
# room: O
# air: Biological_structure
# chest: Sign_symptom
# radiography: O
# revealed: Biological_structure
# bilateral: Biological_structure
# opacities: Biological_structure
# consistent: O
# pulmonary: Detailed_description
# edema: Distance
# patient: Therapeutic_procedure
# admitted: Medication
# intensive: Medication
# care: Medication
# unit: Medication
# management: Dosage
# acute: Dosage
# decompensated: History
# heart: Date
# failure: Nonbiological_location
# started: History
# intravenous: History
# diuretics: Duration
# inotropic: O
# support: O
# dobutamine: O
# next: O
# several: O
# days: O
# symptoms: O
# improved: O
# discharged: O
# home: O
# instructions: O
# follow: O
# primary: O
# care: O
# provider: O
# 1: O
# week: O
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     57
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# -
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# -
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
#
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     man
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sex</span>
# </mark>
#
# <mark class="entity" style="background: #f7a399; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     presented
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nonbiological_location</span>
# </mark>
#  to the
# <mark class="entity" style="background: #f7a399; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     emergency
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nonbiological_location</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     department
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  with a
# <mark class="entity" style="background: #f1f0d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Date</span>
# </mark>
# -day
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     history
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#  of
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     worsening
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#
# <mark class="entity" style="background: #9ddfd3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     shortness
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Biological_structure</span>
# </mark>
#  of
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     breath
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#  and chest
# <mark class="entity" style="background: #f7a399; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nonbiological_location</span>
# </mark>
# . He
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     reported
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  no
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     recent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     travel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  or
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sick
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     contacts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# . His
# <mark class="entity" style="background: #f7a399; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     medical
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nonbiological_location</span>
# </mark>
#
# <mark class="entity" style="background: #f7a399; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     history
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nonbiological_location</span>
# </mark>
#  was
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     significant
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  for
# <mark class="entity" style="background: #f7a399; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hypertension
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nonbiological_location</span>
# </mark>
# ,
# <mark class="entity" style="background: #f7a399; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dyslipidemia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nonbiological_location</span>
# </mark>
# , and
# <mark class="entity" style="background: #f7a399; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     type
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nonbiological_location</span>
# </mark>
#
# <mark class="entity" style="background: #9ddfd3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Biological_structure</span>
# </mark>
#
# <mark class="entity" style="background: #c5b4e3; padding: 0.45e

# %% [markdown]
# ## MODEL 3

# %%
NER("model_3",
        "A 57-year-old man presented to the emergency department with a 2-day history of worsening shortness of breath and chest pain. He reported no recent travel or sick contacts. His medical history was significant for hypertension, dyslipidemia, and type 2 diabetes mellitus. On examination, he was tachycardic and tachypneic, with oxygen saturation of 88% on room air. Chest radiography revealed bilateral opacities consistent with pulmonary edema. The patient was admitted to the intensive care unit for management of acute decompensated heart failure. He was started on intravenous diuretics and inotropic support with dobutamine. Over the next several days, his symptoms improved and he was discharged to home with instructions to follow up with his primary care provider in 1 week.")
# Out:
# Model provided:  Bidirectional LSTM model with BioWordVecEmbedding Layers followed two LSTM layers and one Hidden Dense Layer
# 1/1 [==============================] - 1s 686ms/step
# Predicted Named Entities:
# 57: Age
# year: Age
# old: Age
# man: Sex
# presented: Nonbiological_location
# emergency: Nonbiological_location
# department: Date
# 2: Duration
# day: O
# history: Sign_symptom
# worsening: Sign_symptom
# shortness: Biological_structure
# breath: Sign_symptom
# chest: O
# pain: History
# reported: History
# recent: History
# travel: O
# sick: History
# contacts: History
# medical: History
# history: History
# significant: History
# hypertension: History
# dyslipidemia: History
# type: O
# 2: Sign_symptom
# diabetes: Diagnostic_procedure
# mellitus: Diagnostic_procedure
# examination: Date
# tachycardic: History
# tachypneic: Detailed_description
# oxygen: Biological_structure
# saturation: Diagnostic_procedure
# 88: Detailed_description
# room: O
# air: Distance
# chest: Sign_symptom
# radiography: O
# revealed: Nonbiological_location
# bilateral: Nonbiological_location
# opacities: Nonbiological_location
# consistent: O
# pulmonary: Detailed_description
# edema: Distance
# patient: Distance
# admitted: Administration
# intensive: Medication
# care: Medication
# unit: Medication
# management: O
# acute: Clinical_event
# decompensated: Nonbiological_location
# heart: Clinical_event
# failure: Nonbiological_location
# started: Nonbiological_location
# intravenous: Date
# diuretics: Duration
# inotropic: O
# support: O
# dobutamine: O
# next: O
# several: O
# days: O
# symptoms: O
# improved: O
# discharged: O
# home: O
# instructions: O
# follow: O
# primary: O
# care: O
# provider: O
# 1: O
# week: O
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     57
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# -
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# -
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
#
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     man
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sex</span>
# </mark>
#
# <mark class="entity" style="background: #f7a399; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     presented
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nonbiological_location</span>
# </mark>
#  to the
# <mark class="entity" style="background: #f7a399; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     emergency
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nonbiological_location</span>
# </mark>
#
# <mark class="entity" style="background: #f1f0d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     department
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Date</span>
# </mark>
#  with a
# <mark class="entity" style="background: #ffdfba; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Duration</span>
# </mark>
# -day
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     history
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#  of
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     worsening
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#
# <mark class="entity" style="background: #9ddfd3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     shortness
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Biological_structure</span>
# </mark>
#  of
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     breath
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#  and chest
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# . He
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     reported
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  no
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     recent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  travel or
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sick
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     contacts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# . His
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     medical
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     history
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  was
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     significant
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  for
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hypertension
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# ,
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dyslipidemia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# , and type
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     diabetes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Diagnostic_procedure</span>
# </mark>
#
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mellitus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Diagnostic_procedure</span>
# </mark>
# . On
# <mark class="entity" style="background: #f1f0d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border

# %% [markdown]
# ## MODEL 4

# %%
NER("model_4",
        "A 57-year-old man presented to the emergency department with a 2-day history of worsening shortness of breath and chest pain. He reported no recent travel or sick contacts. His medical history was significant for hypertension, dyslipidemia, and type 2 diabetes mellitus. On examination, he was tachycardic and tachypneic, with oxygen saturation of 88% on room air. Chest radiography revealed bilateral opacities consistent with pulmonary edema. The patient was admitted to the intensive care unit for management of acute decompensated heart failure. He was started on intravenous diuretics and inotropic support with dobutamine. Over the next several days, his symptoms improved and he was discharged to home with instructions to follow up with his primary care provider in 1 week.")
# Out:
# Model provided:  Bidirectional LSTM Model with Time Distributed Dense Layers - Single LSTM layer and Two time distributed dense layers
# 1/1 [==============================] - 0s 352ms/step
# Predicted Named Entities:
# 57: Age
# year: Age
# old: Age
# man: Sex
# presented: Nonbiological_location
# emergency: Nonbiological_location
# department: Date
# 2: Duration
# day: History
# history: Sign_symptom
# worsening: Sign_symptom
# shortness: Sign_symptom
# breath: Sign_symptom
# chest: History
# pain: History
# reported: History
# recent: History
# travel: History
# sick: History
# contacts: History
# medical: History
# history: History
# significant: History
# hypertension: History
# dyslipidemia: History
# type: Diagnostic_procedure
# 2: Biological_structure
# diabetes: Diagnostic_procedure
# mellitus: Diagnostic_procedure
# examination: Lab_value
# tachycardic: Detailed_description
# tachypneic: Detailed_description
# oxygen: Biological_structure
# saturation: Diagnostic_procedure
# 88: Detailed_description
# room: O
# air: Biological_structure
# chest: O
# radiography: O
# revealed: Distance
# bilateral: Nonbiological_location
# opacities: Nonbiological_location
# consistent: O
# pulmonary: O
# edema: Medication
# patient: Medication
# admitted: Administration
# intensive: Medication
# care: Medication
# unit: Medication
# management: Dosage
# acute: Dosage
# decompensated: Nonbiological_location
# heart: Clinical_event
# failure: Medication
# started: Nonbiological_location
# intravenous: Date
# diuretics: Duration
# inotropic: O
# support: O
# dobutamine: O
# next: O
# several: O
# days: O
# symptoms: O
# improved: O
# discharged: O
# home: O
# instructions: O
# follow: O
# primary: O
# care: O
# provider: O
# 1: O
# week: O
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     57
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# -
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# -
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
#
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     man
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sex</span>
# </mark>
#
# <mark class="entity" style="background: #f7a399; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     presented
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nonbiological_location</span>
# </mark>
#  to the
# <mark class="entity" style="background: #f7a399; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     emergency
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nonbiological_location</span>
# </mark>
#
# <mark class="entity" style="background: #f1f0d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     department
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Date</span>
# </mark>
#  with a
# <mark class="entity" style="background: #ffdfba; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Duration</span>
# </mark>
# -
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     history
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#  of
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     worsening
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     shortness
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#  of
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     breath
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#  and
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chest
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# . He
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     reported
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  no
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     recent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     travel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  or
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sick
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     contacts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# . His
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     medical
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     history
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  was
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     significant
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  for
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hypertension
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# ,
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dyslipidemia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# , and
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     type
#     <span style="font-size: 0.8em; font-

# %% [markdown]
# ## MODEL 5

# %%
NER("model_5",
        "A 57-year-old man presented to the emergency department with a 2-day history of worsening shortness of breath and chest pain. He reported no recent travel or sick contacts. His medical history was significant for hypertension, dyslipidemia, and type 2 diabetes mellitus. On examination, he was tachycardic and tachypneic, with oxygen saturation of 88% on room air. Chest radiography revealed bilateral opacities consistent with pulmonary edema. The patient was admitted to the intensive care unit for management of acute decompensated heart failure. He was started on intravenous diuretics and inotropic support with dobutamine. Over the next several days, his symptoms improved and he was discharged to home with instructions to follow up with his primary care provider in 1 week.")
# Out:
# Model provided:  Bidirectional LSTM Model with two LSTM layers and one Hidden Dense Layer
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x2e9af7ca0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 472ms/step
# Predicted Named Entities:
# 57: Age
# year: Age
# old: Age
# man: Sex
# presented: Nonbiological_location
# emergency: Nonbiological_location
# department: Duration
# 2: Duration
# day: O
# history: Sign_symptom
# worsening: Sign_symptom
# shortness: Biological_structure
# breath: Sign_symptom
# chest: History
# pain: History
# reported: History
# recent: O
# travel: O
# sick: O
# contacts: History
# medical: History
# history: History
# significant: History
# hypertension: History
# dyslipidemia: History
# type: O
# 2: O
# diabetes: Diagnostic_procedure
# mellitus: Diagnostic_procedure
# examination: Lab_value
# tachycardic: Detailed_description
# tachypneic: Detailed_description
# oxygen: Biological_structure
# saturation: Diagnostic_procedure
# 88: Detailed_description
# room: O
# air: Biological_structure
# chest: Sign_symptom
# radiography: O
# revealed: Nonbiological_location
# bilateral: Nonbiological_location
# opacities: Nonbiological_location
# consistent: O
# pulmonary: Detailed_description
# edema: Therapeutic_procedure
# patient: Distance
# admitted: Administration
# intensive: Medication
# care: Medication
# unit: Medication
# management: O
# acute: O
# decompensated: Nonbiological_location
# heart: Clinical_event
# failure: O
# started: Nonbiological_location
# intravenous: Duration
# diuretics: Duration
# inotropic: O
# support: O
# dobutamine: O
# next: O
# several: O
# days: O
# symptoms: O
# improved: O
# discharged: O
# home: O
# instructions: O
# follow: O
# primary: O
# care: O
# provider: O
# 1: O
# week: O
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     57
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# -
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# -
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
#
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     man
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sex</span>
# </mark>
#
# <mark class="entity" style="background: #f7a399; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     presented
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nonbiological_location</span>
# </mark>
#  to the
# <mark class="entity" style="background: #f7a399; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     emergency
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nonbiological_location</span>
# </mark>
#
# <mark class="entity" style="background: #ffdfba; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     department
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Duration</span>
# </mark>
#  with a
# <mark class="entity" style="background: #ffdfba; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Duration</span>
# </mark>
# -day
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     history
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#  of
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     worsening
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#
# <mark class="entity" style="background: #9ddfd3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     shortness
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Biological_structure</span>
# </mark>
#  of
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     breath
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#  and
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chest
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# . He
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     reported
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  no recent travel or sick
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     contacts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# . His
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     medical
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     history
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  was
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     significant
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  for
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hypertension
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# ,
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dyslipidemia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# , and type 2
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     diabetes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Diagnostic_procedure</span>
# </mark>
#
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mellitus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Diagnostic_procedure</span>
# </mark>
# . On
# <mark class="entity" style="background: #f4b3c2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     examination
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Lab_value</span>
# </mark>
# , he was
# <mark class="entity" style="background: #ffb347; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tachycardic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Detailed_description</span>
# </mark>
#  and
# <mark class="entity" style="background: #ffb347; padding: 0.45

# %% [markdown]
# ## MODEL 6

# %%
NER("model_6",
        "A 57-year-old man presented to the emergency department with a 2-day history of worsening shortness of breath and chest pain. He reported no recent travel or sick contacts. His medical history was significant for hypertension, dyslipidemia, and type 2 diabetes mellitus. On examination, he was tachycardic and tachypneic, with oxygen saturation of 88% on room air. Chest radiography revealed bilateral opacities consistent with pulmonary edema. The patient was admitted to the intensive care unit for management of acute decompensated heart failure. He was started on intravenous diuretics and inotropic support with dobutamine. Over the next several days, his symptoms improved and he was discharged to home with instructions to follow up with his primary care provider in 1 week.")
# Out:
# Model provided:  Bidirectional LSTM model with BioWordVecEmbedding Layers followed two LSTM layers and one Hidden Dense Layer
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x2d5fc0f70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 312ms/step
# Predicted Named Entities:
# 57: Age
# year: Age
# old: Age
# man: Sex
# presented: Nonbiological_location
# emergency: Nonbiological_location
# department: Date
# 2: Date
# day: O
# history: Sign_symptom
# worsening: Sign_symptom
# shortness: Biological_structure
# breath: Sign_symptom
# chest: O
# pain: History
# reported: History
# recent: History
# travel: History
# sick: History
# contacts: History
# medical: History
# history: History
# significant: History
# hypertension: History
# dyslipidemia: History
# type: Diagnostic_procedure
# 2: Detailed_description
# diabetes: Diagnostic_procedure
# mellitus: Diagnostic_procedure
# examination: O
# tachycardic: Detailed_description
# tachypneic: Detailed_description
# oxygen: Biological_structure
# saturation: Diagnostic_procedure
# 88: Detailed_description
# room: O
# air: Biological_structure
# chest: Sign_symptom
# radiography: O
# revealed: Distance
# bilateral: Distance
# opacities: Nonbiological_location
# consistent: O
# pulmonary: Detailed_description
# edema: Distance
# patient: Distance
# admitted: Medication
# intensive: Medication
# care: Therapeutic_procedure
# unit: Medication
# management: Dosage
# acute: Dosage
# decompensated: Dosage
# heart: Dosage
# failure: Nonbiological_location
# started: Nonbiological_location
# intravenous: Date
# diuretics: Date
# inotropic: O
# support: O
# dobutamine: O
# next: O
# several: O
# days: O
# symptoms: O
# improved: O
# discharged: O
# home: O
# instructions: O
# follow: O
# primary: O
# care: O
# provider: O
# 1: O
# week: O
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     57
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# -
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# -
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
#
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     man
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sex</span>
# </mark>
#
# <mark class="entity" style="background: #f7a399; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     presented
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nonbiological_location</span>
# </mark>
#  to the
# <mark class="entity" style="background: #f7a399; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     emergency
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nonbiological_location</span>
# </mark>
#
# <mark class="entity" style="background: #f1f0d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     department
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Date</span>
# </mark>
#  with a
# <mark class="entity" style="background: #f1f0d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Date</span>
# </mark>
# -day
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     history
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#  of
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     worsening
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#
# <mark class="entity" style="background: #9ddfd3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     shortness
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Biological_structure</span>
# </mark>
#  of
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     breath
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#  and chest
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# . He
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     reported
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  no
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     recent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     travel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  or
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sick
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     contacts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# . His
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     medical
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     history
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  was
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     significant
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  for
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hypertension
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# ,
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dyslipidemia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# , and
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     type
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Diagnostic_procedure</span>
# </mark>
#
# <mark class="entity" style="background: #ffb347; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Detailed_description</span>
# </mark>
#
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     diabetes

# %% [markdown]
# ## MODEL 7

# %%
NER("model_7",
        "A 57-year-old man presented to the emergency department with a 2-day history of worsening shortness of breath and chest pain. He reported no recent travel or sick contacts. His medical history was significant for hypertension, dyslipidemia, and type 2 diabetes mellitus. On examination, he was tachycardic and tachypneic, with oxygen saturation of 88% on room air. Chest radiography revealed bilateral opacities consistent with pulmonary edema. The patient was admitted to the intensive care unit for management of acute decompensated heart failure. He was started on intravenous diuretics and inotropic support with dobutamine. Over the next several days, his symptoms improved and he was discharged to home with instructions to follow up with his primary care provider in 1 week.")
# Out:
# Model provided:  Bidirectional LSTM CRF model with BioWordVecEmbedding Layers followed two LSTM layers and Time Distirbuted Dense Layers followed by CRF Layer
# 2023-04-09 13:08:39.748333: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 1/1 [==============================] - 0s 439ms/step
# Predicted Named Entities:
# 57: Age
# year: Age
# old: Age
# man: Sex
# presented: Nonbiological_location
# emergency: Nonbiological_location
# department: Duration
# 2: Duration
# day: O
# history: Sign_symptom
# worsening: Sign_symptom
# shortness: Biological_structure
# breath: Sign_symptom
# chest: O
# pain: History
# reported: History
# recent: History
# travel: O
# sick: O
# contacts: History
# medical: History
# history: History
# significant: History
# hypertension: History
# dyslipidemia: History
# type: O
# 2: Sign_symptom
# diabetes: Medication
# mellitus: Diagnostic_procedure
# examination: Lab_value
# tachycardic: Detailed_description
# tachypneic: Detailed_description
# oxygen: Biological_structure
# saturation: Diagnostic_procedure
# 88: Detailed_description
# room: O
# air: Biological_structure
# chest: Sign_symptom
# radiography: O
# revealed: Nonbiological_location
# bilateral: Nonbiological_location
# opacities: Nonbiological_location
# consistent: O
# pulmonary: Detailed_description
# edema: Distance
# patient: Distance
# admitted: Administration
# intensive: Medication
# care: Medication
# unit: Medication
# management: O
# acute: O
# decompensated: Nonbiological_location
# heart: Clinical_event
# failure: Nonbiological_location
# started: Nonbiological_location
# intravenous: Date
# diuretics: Date
# inotropic: O
# support: O
# dobutamine: O
# next: O
# several: O
# days: O
# symptoms: O
# improved: O
# discharged: O
# home: O
# instructions: O
# follow: O
# primary: O
# care: O
# provider: O
# 1: O
# week: O
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     57
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# -
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# -
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
#
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     man
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sex</span>
# </mark>
#
# <mark class="entity" style="background: #f7a399; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     presented
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nonbiological_location</span>
# </mark>
#  to the
# <mark class="entity" style="background: #f7a399; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     emergency
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nonbiological_location</span>
# </mark>
#
# <mark class="entity" style="background: #ffdfba; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     department
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Duration</span>
# </mark>
#  with a
# <mark class="entity" style="background: #ffdfba; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Duration</span>
# </mark>
# -day
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     history
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#  of
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     worsening
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#
# <mark class="entity" style="background: #9ddfd3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     shortness
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Biological_structure</span>
# </mark>
#  of
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     breath
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#  and chest
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# . He
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     reported
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  no
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     recent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  travel or sick
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     contacts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# . His
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     medical
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     history
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  was
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     significant
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#  for
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hypertension
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# ,
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dyslipidemia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
# , and type
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
#
# <mark class="entity" style="background: #f9d5e5; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     diabetes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Medication</span>
# </mark>
#
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mellitus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Diagnostic_procedure</span>
# </mark>
# . On
# <mark class="entity" style="background: #f4b3c2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     examination
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Lab_value</span>
# </mark>
# , he was
# <mark class="entity" style="background: #ffb347; padding: 0.45em 0.6em; margin: 0 0.25em; line-h
